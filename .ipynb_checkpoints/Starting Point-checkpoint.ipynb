# %% [markdown]
# # Library and Data Preparation

# %%
import os
import fnmatch
import TWB.xliff as xliff
import spacy
import pandas as pd
import queue
import numpy as np
import unicodedata

# %%
# normalize unicode characters
def NFD(s):
        return unicodedata.normalize('NFD', s)

# put your data path here
data_dir = '/home/marios/Desktop/Marios/Personal/repos/JuSiPy_TWB/data/'
metadata = pd.read_excel(data_dir + 'Hackathon-for-Good-2019_TWB-Challenge_Metadata.xlsx')

# choose only text documents
# TODO The metadata contain some files multiple times and the table is almost 3 times the number of documents
# Using various combinations of subsets of the columns to get all the 12156 documents did not succeed
accepted_documents = metadata.loc[(metadata['Format'] == 'doc') | (metadata['Format'] == 'pdf')].drop_duplicates()

# fix some problems with the encoding of special characters in filenames
accepted_documents['Filename'] = accepted_documents['Filename'].apply(NFD)

# update data path with the sdlxliff directory
data_dir += 'hackathon-for-good-2019_TWB-challenge_files/'

# %%
# store all sdlxliff filenames into a list
document_names = []

# trying to get all doc documents based on extensions
for document in os.listdir(data_dir):    
    if fnmatch.fnmatch(document,'*.sdlxliff'):
        if fnmatch.fnmatch(document,'*.doc*'):
            document_names.append(document)
        if fnmatch.fnmatch(document,'*.DOC*'):
            document_names.append(document)
        if fnmatch.fnmatch(document,'*.txt*'):
            document_names.append(document)    
        if fnmatch.fnmatch(document,'*.pdf*'):
            document_names.append(document)
        if fnmatch.fnmatch(document,'*.PDF*'):
            document_names.append(document)
        if fnmatch.fnmatch(document,'*.odt*'):
            document_names.append(document)
        if fnmatch.fnmatch(document,'*.rtf*'):
            document_names.append(document)
        if fnmatch.fnmatch(document,'*.dotx*'):
            document_names.append(document)

# %%
# get the translated contents of all documents
document_contents = []

for document in list(document_names):
    # Avoid a couple of (probably) malformed xml documents(No root found by the parser)
    try:
        document_contents.append(xliff.XLIFF(data_dir + document).target)
    except AttributeError:
        print(document)
        document_names.remove(document)
        continue

# %%
# same unicode fix as for accepted_documents
for i in range(len(document_names)):
    document_names[i] = NFD(document_names[i])

# %%
# remove the sdlxliff extension from the document names as most files in the metadata are without it
filenames = []
for name in document_names:
    filenames.append(name.replace('.sdlxliff', ''))

# %%
# find the documents that most probably have no metadata, they are a lot
documents_without_metadata = []

count = 0
for name in filenames:
    temp = accepted_documents.loc[accepted_documents['Filename'] == name]
    if temp.empty:
        # for the special case that the translated version's extension is used
        temp2 = accepted_documents.loc[accepted_documents['Filename'] == name + '.sdlxliff']
        if temp2.empty:
            count += 1
        documents_without_metadata.append(name)

print(count)
# Out:
# 2734

# %%
# find the few entries in the metadata that are not in the documents 
# and the corresponding document filenames for the metadata filenames with weird special characters
import difflib

filename_correspondence = {}
count = 0
for name in list(accepted_documents['Filename'].drop_duplicates()):
    if name not in filenames and name not in document_names:
        max_similarity = 0.0
        corresponding_document = None
        for filename in filenames:
            # filename letter similarity
            seq = difflib.SequenceMatcher(None, filename, name)
            if (seq.ratio() > max_similarity):
                max_similarity = seq.ratio()
                corresponding_document = filename
        # this threshold was manually checked and it produces only one false positive
        if max_similarity > 0.5:
            filename_correspondence[name] = corresponding_document
        else:
            count += 1
            print(name)

# delete the false positive 
del filename_correspondence['Patient_Release_Form_-_Final_4.25.docx']                
count
# Out:
# Ø·Ø¹Ø§ÙÙÙ_Ø§ÙÙÙÙ.docx
# åäººèªå³.docx
# 2

# %%
found = []
nfound = []
for title in documents_without_metadata:
    p = len(accepted_documents[accepted_documents.Filename==title])
    if p > 1:
        found.append(title)
    else:
        nfound.append(title)

# %%
len(found)
# Out:
# 0

# %%
len(nfound)
# Out:
# 2576

# %%
len(accepted_documents[accepted_documents.Format=='pdf'])
# Out:
# 89

# %%
2788-2734
# Out:
# 54

# %%
filenames
# Out:
# ['Week_1_to_4,__Lesson_1-24.docx',
#  'May_2018_drafts_for_translations.zip___SEP___St_17_Community_Level_Approaches_Version_for_Comment.docx',
#  '9_Regional_HR_instruments_for_translation.docx',
#  'Informed_consent_proforma[1].docx',
#  'SAHALAVA_Part_5__Supplementary_Education_Programme__FR.docx',
#  'How_to_answer_multiple_choice_questions.docx',
#  'A_systematic_review_of_risk_and_protective_factors_associated_with_family_related_violence_in_refugee_families.docx',
#  'table_external_actors_opportunities_and_risks.docx',
#  'Part_2_Banten_Province_Tsunami_Dec_22_2018.docx',
#  '17-CCS-Child-and-Family-Psychosocial-Assessment-Form.docx',
#  'Pill_7.2_El_foso_y_errores.docx',
#  'Hélice-User-Focus-Group-Selection-final.docx',
#  'Translations_2nd_tranche_of_Ebola.zip___SEP___Translations_2nd_tranche_of_Ebola___SEP___Money_2015.docx',
#  'Recent_research_Feb2017.docx',
#  'Privacy_Policy.docx',
#  'Plantilla_Informe_Semanal_Consultores_Bcn.docx',
#  'Community_engagement_in_HNOs__v1_MS.DOCX',
#  'DRAFT_Citizenship_Protocol_EN_Revised_June_2018_for_STC-AMENDED_Malabo_0....docx',
#  'Risk_Assessment_Template.docx',
#  'PSY_S1_T1_Introducao_modulo.docx',
#  'SEC_2019_Offline_Reg_Form_FINAL.docx',
#  'PreventionofAbuse_Policy.docx',
#  'Batch_5_-_for_MY_translation.zip___SEP___2_CCS_Attitude-Scale.docx',
#  'Interview_D20.docx',
#  'Colombia_ciclo_violencias_I.doc',
#  '2018.10.15_Family_Night_Email.docx',
#  'PSY_S4_T4_Pedagogias_Paulo_Freire.docx',
#  'Scripts_and_written_ads.docx',
#  'CwC_Brochure_FINAL.docx',
#  'Note_NBO_-_Recommandations_VF.doc',
#  'BOL12_SODIS_KB2017.docx',
#  'SOP_for_Warehouse_and_Inventory_Management_in_UNHCR_(002)_(1)_EN.docx',
#  'JobDescription-_MAWD_2.doc',
#  'SUN-KM-Sub_National_Exercise_Outline_FINAL.docx',
#  'Key_Messages_Preparedness_draft_27_January_2018.docx',
#  'CURSO_Writing_Funding_Proposals_No._19_to_end_PRT.docx',
#  'SERCOLDES_0717_20_Mon_and_Eval_Report_Part_3.docx',
#  '154802-01_Updated_Safe_and_Well_Cards_English_final.pdf',
#  'Updated_information_for_asylum_seekers_coming_to_the_United_States.docx',
#  'Cooking_with_Kids.docx',
#  'Free_Online_GED_Prep_Classes.docx',
#  'Mathematics_Level_1-converted.docx',
#  'SOP.zip___SEP___SP-026-CT_SOP_Treatment_outcome_v2.1_18Dec2018_clean_(1).docx',
#  'Residency_Curriculum_Glaucoma_Section.docx',
#  '2018.07.17_QuitStigma-Recommendations-Health-Professionals-en.docx',
#  'LMS_user_guide.doc',
#  'a_plain_document.txt',
#  '43_Hunt.docx',
#  'Spring_2019_Family_Newsletter.docx',
#  'INEE_Blog_Instructions_(all_lang).docx',
#  'ACF_docs.zip___SEP___Charge_de_travail.docx',
#  'AZURE_OPTIONS.docx',
#  'ENN.zip___SEP___ENN___SEP___220_fa_56_IYCFE_Michele_11_to_NickNM_amended_clean.docx',
#  'carl_callison_-_greed_and_addiction.doc',
#  'Maths_Level1_-_170918.docx',
#  'Wapsi_comprar_lo_mismo_de_siempre_al_mismo_precio_y_ser_solidario.docx',
#  'PandrTB_ICD_Minor_Participants_V1.9_26Jun2018_.docx',
#  'REU_Mexico_opium_ENG.docx',
#  'Summaries_for_translation.zip___SEP___Summaries_for_translation___SEP___Leitmeyer_2011.docx',
#  'GBV_RP_TWB.docx',
#  'May_2018_drafts_for_translations.zip___SEP___St_18_Safer_Societies__Version_for_Comment.docx',
#  'Forecast_Based_Early_Action_timeline_v7_FOR_TRANSLATION.docx',
#  'Board_Member_Newsletter_Sept_2017.docx',
#  'CLIN.018B.01__ZMapp_Clinical_Accountability_2017.08.23_clean.docx',
#  'UMBURANAS_External_Evaluation_Mar_18_PRT_Part_1.docx',
#  'CESOLES_Medium_applic_Part_2__SP.docx',
#  'the_screening_interview.docx',
#  '201808_RA2017_-_02_ODD_et_réseau_FR.docx',
#  '201806_Las_nuevas_adicciones-ES.docx',
#  'HRMI_Survey_Deadline_Extension_(1).docx',
#  'Finland_-_PSP_USE_THIS_(1).docx',
#  'Doc_Round.docx',
#  'Fall_2017_College_Possible_Newsletter.docx',
#  '4._Key_responsibilities_of_a_CM_agency_(final).docx',
#  'MSP_-_Summary_-_FINAL_FOR_ORNA.DOCX',
#  'Draft_2019_Survey_Email_ENGLISH_with_updated_date.docx',
#  'Another_year_of_fear_and_mysterious_future-HB.odt',
#  'Interventions_for_treating_scabies.docx',
#  'Rapport_GERES_2014D_Projet_Central_HighlandsVF-Part_2_-_Copie.docx',
#  'BA_Cameroon.zip___SEP___IMG_20171026_0016.pdf',
#  'IDP_16293_Li_EN.docx',
#  'Innovative_Approaches_to_Expanding_Access_to_Medication_Final.docx',
#  'Clinical_OPD_Form_Questions.docx',
#  'Research_Protocol_Practice_Run_Stigma_Reduction_-_Analysis_Tool_(DRC)_18May2018_v6.docx',
#  'violenza_sui_bambini.docx',
#  'No_6_-_System_Handover,_Operation_and_Maintenance_Plan.docx',
#  '2018_Task_04_Oxygen_Therapy.docx',
#  'Figure_1_Page_33.docx',
#  'Exit_Survey_Cameroon.zip___SEP___IMG_20171026_0018.pdf',
#  'IFRC_-operation_final_report_-_15_October_2013.docx',
#  'Appointments_with_Bureau_Des_Etrangers.pdf',
#  '201804_Partners_for_Review_Meeting_EN.docx',
#  'PSEA_SH_presentation_SWS_Nov_2018.docx',
#  'IMC_1.zip___SEP___IMC_1___SEP___53_Yaasimiin_Maxmaed_Kaahin_.docx',
#  'Présentation_du_groupe_de_travail_migrations.docx',
#  'CCFD_-_Terre_Solidaire_sur_le_Syndode_Pan-Amazonien.docx',
#  'Global_Partner_Safety_Audit_Checklist_8_2018.docx',
#  'LAOS_UDIN_Nutrition_KB_2017_red.docx',
#  'IDOP-D-17-00203_Abstract_EN.docx',
#  'Zika7.zip___SEP___Zika7___SEP___Ramos-castaneda2017-dengueSR_Isla_SL.docx',
#  'GrievanceProceduresFrameworkForHRjanuary2018.docx',
#  '4th_p15SupportingNorlha_EN.docx',
#  'Abolition_of_Chair_position.doc',
#  '201804_Texto_cuestionario_Perspectiva_de_género_(1).docx',
#  'S.3.1__Finance_Management_3.6_Final_version-Option_2.docx',
#  '20180125_info_Fr.doc',
#  'Big_Wind_Blows.docx',
#  "Don't_Fall_For_It.docx",
#  'ZUS_decision_about_Polish_Pension.pdf',
#  'kenyanpopulationcouncildocumentsx4.zip___SEP___Appendices_for_translation.doc',
#  'contentObjects.docx',
#  'IMC_1.zip___SEP___IMC_1___SEP___6._FAADUMO_NAKRUUMA.docx',
#  'IDP_18215_EN.docx',
#  'A_Domain_French_Version_-_for_checking_French_version_of_the_user_commands_(see_screenshots).zip___SEP___A3_French.docx',
#  'PSY_S3_T1_Ideologia.docx',
#  'Reduce_Pain_with_Better_Arthritis_Health_and_Wellness.docx',
#  'A3_Annual_Programme_Report_User_guide_(1).docx',
#  'WASH_MESSAGES_–_FOR_TRANSLATION_(5)_hausa.docx.xlf',
#  'Manual_Orientation_to_FRR_2014v2.docx',
#  'Synthesis_strategy_Egypt.docx',
#  'BIP-B_S2T2_Seeking_telling_truth.docx',
#  '200_fa_56_Somalia_AAP_11NMfinal.docx',
#  'Working_with_broadcasters_FOR_TRANSLATION.DOCX',
#  '2._Module_9_Feedback_exercise_2.doc',
#  'Transcripcion-Taking_Coaches_C1__C2_-_FGD_-_LUZA_(002).docx',
#  'IMS_55-68.zip___SEP___64_Aamina_Cabdi_Warsame_.docx',
#  'FGD_-_Adolescent_14-17,_Final_-_ENG.docx',
#  'FAQ_leaflet_FINAL_26.6.2017.docx',
#  'D2P_Quartely_Review_Tool_version_1.5._EXAMPLE.doc',
#  'animation_script_en.docx',
#  'community_profile_pdf.docx',
#  'ShelterFundamentalsParticipantGuide_(2).doc',
#  'Short_Children_Drama_Scripts_7145.4.zip___SEP___43._MULKI_NUUR.docx',
#  'Wheelchair_Workbook-Branding_included.pdf',
#  'JD_Cash_Transfer_Delegate_.docx',
#  'SOR_Sorgenfri_editor_day_as_a_vendor_NOR_NEEDS_TRANS.docx',
#  'Anaesthesia_for_hip_fracture_surgery_in_adults.docx',
#  'A_systematic_review_of_psychosocial_interventions_for_adult_refugees_and_asylum_seekers.docx',
#  'SmileTrain_Training_Evaluation_Final.docx',
#  'Link_to_answers_2.docx',
#  'Womanity_Award_website_copy_To_translators.docx',
#  "International_Women's_Day__Radio_Nisaa_Interview_(1).docx",
#  'LUX_Proposition_TDHL__Nicaragua-_per_TWB.docx',
#  'Gangliosides_for_acute_spinal_cord_injury.docx',
#  '138_fa_55_porridgemums_9NM.docx',
#  'Understanding-and-Monitoring-Diabetes-Outline.docx',
#  'OPSIDIANET_CAPITOLO_3.docx',
#  '01_To_be_reviewed_by_ST_partner.zip___SEP___CP_SPEECH_12-24_mos_04_Schedule_appointment_for_speech_evaluation.docx',
#  'INEE_Data_and_Evidence_webpage_update_survey.docx',
#  'IASC.Hum_System_Wide_Emergency_Activation_definition___procedures.2012.docx',
#  'SES-PIC-PR-14_Inducción_de_Esputo_por_Nebulización_EN.docx',
#  'Basic_Principles_in_Palliative_Care.docx',
#  '613_rs_54_MSNP_Nepal_11_FINAL_to_NickNM_AMEND.docx',
#  'wiki.zip___SEP___wiki3.docx',
#  'CEPA_1118_15__Part_6__Port__result_1.docx',
#  'SALESFORCE_Large_Single_Year_Proposal_Form_EN_Part_2_Section_3_and_4.docx',
#  'SmileTrain_Training_Agenda_2018JULY_Final.docx',
#  '1._CSC_Membership_Description_2018.docx',
#  'cccm.zip___SEP___3._Module_1_-_CCCM_framework_and_national_authorities_(final).doc',
#  '2019_Chinese12Zodiacs_part4.docx',
#  'importanttranslationforpleaguetreatmentcenterin.zip___SEP___10_SOP__Cleaning_toilet_and_Shower_in_High-Risk_Areas_-_IPC_-_Copy.docx',
#  'Survey_Question_Explanation_and_Tips_RAS.docx',
#  'Solar_Eclipse_Information_for_Refugees_and_Immigrants.docx',
#  '4_CONNECT_Artwork_Packaging_v1.docx',
#  'PR_S2_T1_Introducao_seccao_2.docx',
#  'Colloids_versus_crystalloids_for_fluid_resuscitation_in_critically_ill_patients.docx',
#  'Guadeloupe.docx',
#  'Group_Work_-_Case_Study_4.docx',
#  '20180308_info_Fr.doc',
#  'Racism_gender_equipment.odt',
#  'WEI_Advocacy_Guide_-_Part_3_for_Translation.docx',
#  'MRVG_Part_11.docx',
#  'Stiftelsesdokument_for_Mak-a-Wish_Norge_-_endelig_22.6.17.docx',
#  'To_translate_-_Associations_in_Calais.odt.docx',
#  'To_translate_-_Associations_in_Calais.odt.docx',
#  'Protocol_II_Technical_Maintenance_-_Syringe_Pump_BBraun_Perfusor_Compact.docx',
#  'Interventions_for_impetigo.docx',
#  'WABA_files_for_translation.zip___SEP___2017_WBW_-_ACTION_FOLDER_Page_6(final).doc',
#  'CSC_RNDF_2019_Application_Form_-_CESIP.docx',
#  '02_TEMPLATE_protocol_VCS_v1.1_May2017_Final.doc',
#  'Medical_Missions_Flyer-_In_Country_Therapists.docx',
#  'Discover_Your_Career_Interests_Skills_and_Values.docx',
#  'Copy_of_Pre_Competence_Assessment.docx',
#  'CEPA_new_application_Part_2__PORT.doc',
#  'Transcripts_of_audios_6.docx',
#  'IFP_ADVOCACY_UPDATE-MARCH_2018.docx',
#  '2017_WBW_POSTER_-_Text_Only.doc',
#  'Humanity_Road_Healthcare_Situation_Report,_Hurricane_Harvey,_TX,_Sep_1,_2017.docx',
#  '425_squeac_new.docx',
#  'Workshop_design_-_LDP_Chile_2018.docx',
#  'MOZ_Rapid_Assessment_Report_5-Apr_FINAL.docx',
#  'HEAT Antenatal Care (part one) 9_NA.docx',
#  '201710_FP_Mali_FRpourTSF.docx',
#  '1._Module_2_-_Humanitarian_Principles_(final).doc',
#  'Rezaei_Progress_Report_-_Russian.docx',
#  'Concern_WASH_Strategy_2016_-_2020.docx',
#  'Interview_D19.docx',
#  '01_To_be_reviewed_by_ST_partner.zip___SEP___CP_SPEECH_0-12_mos_06_Prep_for_speech_eval.docx',
#  'PIND_P5_S1_U5_C_Parceria_em_Desenvolvimento.docx',
#  'Umburanas_MOU_signed_PRT.docx',
#  '1.2_JJ_FR_Indicateurs_prog_DDC_Diversion.docx',
#  'Questionnaire_Children,_Age_group_13-15_yrs._Lagadikia,_Koutsochero_and_Volos.docx',
#  'ToR_Advisory_Council_revised__final_March_2012.doc',
#  'Social_determinants_of_mid_to_long_term_disaster_impacts_on_health.docx',
#  'February_Newsletter_2019.docx',
#  'Barth,_IPAF,_SCAD,_NET,_Mito,_Sarcoglycanopathies,_HAE,_Ichthyosis,_Glycogen,_SMA.docx',
#  'IOM_Complaints._Gubio_March_2019.docx',
#  'Executive_Summary_-_Prevention_Policy_and_Procedure_Checklist_-_Report_the_Abuse_-_August_2016.docx',
#  'SALESFORCE_Medium_Single_Year_Report_Full_form_0916_09_SP_Section_2.docx',
#  'Roses_Article.docx',
#  'Thailand.odt',
#  'GBV_Briefing_Paper_Part_2.docx',
#  'PCA_Emails.docx',
#  '2967_UCA_San_Juan_del_Río_Coco.doc',
#  'Fiche_individuelle_Information_&_Déclaration_-_Prestataires_v2.0.docx',
#  'RTE_GIESCR_Methodological_Guide_Privatisation_and_Human_Rights_2016_En.docx',
#  '201904_best_practices_-_action_du_gradh_au_togo_FR.docx',
#  'Rules_on_sexual_conduct_for_humanitarian_workers_-_plain-language_version_23-03-18_(1).docx',
#  'RADIO_SCRIPT_–_BASIC_GUIDANCE_ON_SHELTER_UPGRADING.docx',
#  'SHE_Sex_education_GREEK_NEEDS_TRANS.docx',
#  'Rezaei_Progress_Report_-_Spanish.docx',
#  "RA_Réseau_EN.zip___SEP___Réseau_d'Education_Nouvelle_IV.odt",
#  'cccm.zip___SEP___4._Module_1_-_Mixed_migration_flows_(Refugees_and_migrants).docx',
#  '201707_Partnership_for_development_HLPF.docx',
#  'Accord_reduction_duree_des_mandats__VF.DOC',
#  'EPoA_-_EA_Reporting_Procedures_Guidelines_-_9_December_2013_5.docx',
#  'Emergency_Welfare_Inquiry_Form.docx',
#  'Balance_for_Better__Let’s_invest_in_more_women_entrepreneurs.docx',
#  'Chapter_Four_(44-59).docx',
#  "IO2_TRAINER'S_TOOLKIT_DEF.DOCX",
#  'Climate_Change_UPDATE.docx',
#  'StoryboardOCHAInductionModule3_Source_file.docx',
#  'FRR_Session_6_Manual_Working_with_International_Agencies__2014v2.docx',
#  'JobDeskCountrySecurityReferent.docx',
#  'Interventions_for_children_affected_by_armed_conflict_a_systematic_review_of_mental_health_and_psychosocial_support_in_low_and_middle_income_countries.docx',
#  '21_Selwyn.docx',
#  'World_Hospice_and_Palliative_Care_Day_2018_Key_Messages.docx',
#  'PED-B_MW_S2_T6_Aquecimento_global.docx',
#  'Source_files-20180920T133037Z-001.zip___SEP___Source_files___SEP___Recommended_Machete_Design.docx',
#  'OliverTwist-Chapter-1-US-ASCII.txt',
#  'cccm.zip___SEP___1._MODULE_7-02-REV.docx',
#  '12_TEMPLATE_quest_Full_vacc_history_EN_v1.1_May2017_Final.docx',
#  'BRONZE_Guide_1_-_Welcome_Guide_&_Getting_Started.docx',
#  '20180520_Concept_Note_Cash_PMO_HOST_(1).docx',
#  '201708_Human-rights_and_the_SDGs_-SKR.docx',
#  'Get_promoted.docx',
#  'The_use_of_Ivermectin_in_a_rabies_vaccination_campaign_2__LT.docx',
#  '3_CCS_Communication-Assessment-ToolCCS-CA.docx',
#  'reviewers.docx',
#  '2018-PSP-Revision_Epidemic_Diseases_in_Nigeria.docx',
#  '2018.24.07_Learning-Provider-Standards_Pilot-Version.docx.xlf',
#  'Evidence-based_clinical_guidelines_for_immigrants_and_refugees.docx',
#  'IDOP-D-18-00182_Abstract_EN.docx',
#  'Wheelchair_Container_Report_-_edited.docx',
#  'Ivermectin_and_permethrin_for_treating_scabies.docx',
#  'CoD.Seville-Agreement.1997.docx',
#  'FIRST_AID_POLICY_Eng_-_adopted_2007.doc',
#  'Manual_Inventario_LEGO.docx',
#  'Final_draft_Liberia_-_CHI_story_SR_210918_rev.docx',
#  'Student_contacts.zip___SEP___Accepted_Student_Template.docx',
#  'Pulse_oximetry_for_perioperative_monitoring.docx',
#  'Elements_of_the_Container.doc',
#  'Rencontres_internationales_2018_-_Ceméa.odt',
#  'Ireland_information_for_newcomers.docx',
#  'Develop_to_Perform_Frequently_Asked_Questions_V6.docx',
#  'Max_Havelaar_France_-_Projet__Associatif_(1).docx',
#  'IMS_2_web_text_for_multi-language_translation.docx',
#  'TIC_S2_T2_Seguranca_digital.docx',
#  'Children_and_Youth_Mental_Health_and_the_SDGs.docx',
#  '201807__HLPF_EN_SainaraKR.docx',
#  'White_sutton_syndrome_description.docx',
#  'Sexual_Exploitation_and_Abuse_vs._Sexual_Harassment.docx',
#  'App_info_for_registration_process.docx',
#  'IDP_17240_Uddén.docx',
#  'IDP_18062_EN.docx',
#  'Training_Needs_Assessment.doc',
#  'Manual_for_caseworkers-Socio-cultural_orientation_EN_(1).docx',
#  '2018.07.09_Políticas_de_drogas_y_los_ODS_ES.docx',
#  'PED-B_MW_S2_T2_Descobertas_importantes.docx',
#  'flip_cjart_draft_3-10_7-2.docx',
#  'E._F._G._Three_kinds_of_change,_resistance_to_change_and_Horizontal_learning.docx',
#  'Master_HRMI_Survey_2019_no_Q_1.1.-1.3_FOR_TRANSLATION.docx',
#  'Analyser_les_causes_d_un_manque_de_performance.docx',
#  'The_Casspir_Project.odt',
#  'NE.8_Note_sur_les_Audits_financiers.docx',
#  'Copy_of_Men_s_sessions_plan_cycle_1.docx',
#  'PSY_S4_T7_Mitos_desenvolvimento_cerebro.docx',
#  'Safe_Space_for_Women_and_Girls.docx',
#  'Recueil_du_consentement_Candidat.e.s_v2.0.docx',
#  'CPMS_update_document_revised_09_October.docx',
#  'legal_notice.doc',
#  'Manual_w_out_drill_instructions.docx',
#  'Agnes_Korir_article.docx',
#  'CAFE_newsletter_Apr_2017_for_translation_1.docx',
#  'IMS_55-68.zip___SEP___63_Maryan_Cali_Cabsiiye_.docx',
#  'AAACM__Jovems_Report_for_Oct_17_1st_half.docx',
#  'Texte_Sylvie_Nahum_FR_-_copie.docx',
#  '201802_Premio_PORT_ES.docx',
#  'A.1._Introduction-to-Critical-Incident_Response.docx',
#  'August201_Newsletter.docx',
#  'PED-B_WP_S3_T1_Novos_modelos.docx',
#  '2018-PSP-Revision_Borno_Health_sector_Bulletin_V2.docx',
#  'Executive_summary_SPA.docx',
#  'Prenatal_12_Apply_for_financial_aid_programs.docx',
#  'DRC_Regional_Refugee_Response_Plan_13_12_2018_for_translation_into_PT_PT.docx',
#  'School_and_community-based_interventions_for_refugee_and_asylum_seeking_children_A_systematic_review.docx',
#  'Personal_behavior-_FINALx.docx',
#  'PED-B_MW_S3_T7_Energia_solar.doc',
#  'C_&_D_Domain_English_Version.zip___SEP___C___D_Domain_English_Version___SEP___C_Set_Up_New_Project_and_Manage_Project_Userguide.docx',
#  'Family_letter.docx',
#  'Heckler_and_Koch_recall_prank.doc',
#  '17-03-27_TWB_HIF_blog_No._1_-_Language,_power_and_aid_effectiveness.docx',
#  '2._Revised_Draft_FAQ_13_July_.docx',
#  'EDUCAR_Medium_Part_3__SP.docx',
#  'Nutrition_summaries_for_Spanish_translation.zip___SEP___Nutrition_summaries_for_Spanish_translation___SEP___Ramakrishnan_2012.docx',
#  'Balanced_Opioid_systems_for_translation_into_Spanish.docx',
#  'Algemene_programma_capitolo_8.docx',
#  'Diphtheria_campaign__Second_round_v2_CDCfeedback.docx',
#  'Partner_Grant_Agreement_-_Annual_Renewal.docx',
#  'Lay_health_workers_in_primary_and_community_health_care_for_maternal_and_child_health_and_the_management_of_infectious_diseases.docx',
#  'Japan_Country_Report.docx',
#  'My_FMD_story_EN.docx',
#  'Questions_LR_.docx',
#  '17051_IDP_Kassegne_EN.docx',
#  'Home-based-guidance_paper_02112015.docx',
#  'Formulario_de_antecendentes_de_cooperación_Melel_Xojobal.docx',
#  'Outbreak_reporting_template_For_translation.docx',
#  'cafetranslations.zip___SEP___UEFA_and_CAFE_publishes_Disability_Access_Officer_Handbook_v2.docx',
#  'Taiwan_Country_Report_Oct_2018_tracked_changes.docx',
#  'MRVG_Part_6.docx',
#  'BIA_Al_Gore_ENG.doc',
#  'START.zip___SEP___START___SEP___MediaAdvocacy___SEP___Start.MA.GettingStarted.pdf',
#  'IDOP-D-17-00269_Abstract_EN.docx',
#  '20180913_info_Fr.doc',
#  'Short_EN-FR.docx',
#  '418_rs_59_maternal_nutrition_India_7NM.docx',
#  'RUTF_Foundation_Form.docx',
#  'CBR_Step_1.7_Representing_different_points_of_view[1].docx',
#  'PPP_type_expat_FR_new_version_Field_Co_15062017.doc',
#  'CBR_step_3.1_Introduction_to_the_week[1].docx',
#  'A_Good_Negotiator.doc',
#  'FINAL_MOZ_20190417_MultiSectoralRapidAssessment.docx',
#  "Solicitor's_letter_from_France.pdf",
#  'NEAR_Case_studies_-_information_sheet.docx',
#  '8.Post-Op_Poster.docx',
#  'Title_for_translation_-_Effect_of_daily_iron_supplementation_on_health_in_children_aged_4.docx',
#  'CIEP_Needs_Assess_0518_09__Part_1_SP.docx',
#  'First_Significant_Change_Stories.docx',
#  'Guidelines_FR.DOCX',
#  'TOC_01_Instructions_and_checklist_titles_ES.docx',
#  "WEEK_29_-_Anjali's_Kite_SA.docx",
#  '2._Handout_Activity_Why_IYCF-E_is_Important.docx',
#  'Breves_apuntes_para_la_integración_laboral_de_adultos_con_Síndrome_de_Asperger.docx',
#  'UMBURANAS_Medium_July_17_Part_5_PORT.docx',
#  'A_systematic_review_of_the_international_disaster_case_management_literature_in_the_aftermath_of_Hurricane_Katrina.docx',
#  '9_2019_Monkey.docx',
#  'Module_questions_source.zip___SEP___Tier2-Module5-Knowledge-Questions.docx',
#  'B1_Integers.docx',
#  'Letter_of_authorization.docx',
#  'Transcripción_(1).docx',
#  'Roles__Responsibilities_MedRecTL_DRAFT_2017.docx',
#  'NEW_2018_UNDAC_Handbook_1823826E_inside_clean_modif_2.docx',
#  '78_Khadiijo_Axmed_Waasuge_.docx',
#  'Unit_2_additional_text_2109_(1).docx',
#  'Large_Multi-Annual_Report_Form_EN_Part_2.docx',
#  'Planning_an_Open_Cities_Mapping_Project_Final_Task.docx',
#  'Projecten_te_vertalen.docx',
#  'Kabore_P2004a.docx',
#  'Needs_Assessment_Senior.docx',
#  'IMS_2.zip___SEP___83_Faadumo_Hiirad_.docx',
#  'HHIAP_SF_Translation.docx',
#  'Trocaire_Bank_of_Ireland_Proposal_DRC.docx',
#  'Contract_Part_2_for_Trommos_FRENCH.docx',
#  'PR_S2_T4_Factos_mitos_pobre.docx',
#  'FAK_Fight_against_hate_speech_SWE_NEEDS_TRANS.doc',
#  'WEEK_21_-_Healthy_Minds_F_SA.docx',
#  'Safe_and_Well_Registration_Form.doc',
#  '65_Berger.docx',
#  'IFRC.DSA_Lst.January_2015.docx',
#  'May_Newsletter.docx',
#  'Rapport_GERES_2014D_Projet_Central_HighlandsVF-Part_3.docx',
#  'Who_is_left_behind_-_consultation_2_pager._FINAL_for_RC2.docx',
#  'Session_Plan_Template.docx',
#  'Secondary_Stressors_and_Extreme_Events_and_Disasters-A_Systematic_Review_of_Primary_Research_from_2010-2011.docx',
#  'S4.2_Handout_Exercise_1-_Fraud___Corruption_3.6_Version.docx',
#  'What_Matters_Issue_6_combined_English_FINAL.docx',
#  'Lessons_1-2-3.zip___SEP___LESSON_3_-_Breast_Milk_Alternatives_Final_STBrand_26JUN2018.docx',
#  'Lymphangiomatosis_and_Gorham_description_EN.docx',
#  'La_sociología_de_François_Houtart_ext.docx',
#  'AmbarkaBurkinaFaso.doc',
#  'PREGUNTAS_DE_COMPRESIÓN_DE_LA_FORMACIÓN_-_MODELO_DE_COMPETENCIAS_(Respuestas).docx',
#  'TEST_2.docx',
#  'Summaries_for_translation.zip___SEP___Summaries_for_translation___SEP___Missair_2015.docx',
#  'IFRC.DREF_Check_List.2011.doc',
#  'DC_E-Cubed_Launch_email_Round_3_(For_Translation).docx',
#  '201811-16_days_briefing_ES_DEF.docx',
#  '425_rs_59_SQUEAC_coverage_assessment_doubt_5NM_UPDATED_2.docx',
#  'FAQ_PHASE_ONE_Early_Warning_Information_final.docx',
#  'ABTC_records_in_the_Philippines.docx',
#  '5_ICESCR_for_translation.docx',
#  'THINK_EQUAL_Early_Years_Framework_Summary_-_updated_2019.docx',
#  'EnglishtextMVOL.doc',
#  'SERCOLDES_0717_20_Mon_and_Eval_Report_Part_6.docx',
#  '1.1_JJ_FR_Indicateurs_prog_DDC__alternative_det_prov.docx',
#  'Nutrition_summaries_for_Spanish_translation.zip___SEP___Nutrition_summaries_for_Spanish_translation___SEP___Hall_2011.docx',
#  '3)_Baruna_Flooding_Final.docx',
#  'Frequently_Asked_Questions_for_LPG.docx',
#  'BRONZE_Business_Plan_Template.docx',
#  'More_than_the_Money_short_public_doc__for_discussion_FINAL_For_print_(18.7).docx',
#  'Source_files-20180920T133037Z-001.zip___SEP___Source_files___SEP___Budget_-_Field_Tool_and_PPE.docx',
#  '03_Hygiene_promotion_in_Emergencies_-_one_pager_-_final_version.docx',
#  '20170629_IB_Work_Report_IB_Final_(1).docx',
#  'Large_multi-annual_application_2018_SP_Part_7.docx',
#  'Module_8.zip___SEP___MHPSS_T2_tool.docx',
#  'S47_Seeking_Help.docx',
#  'War_profiteer_of_the_month_Magforce.doc',
#  'Partner_Approach_Overview.docx',
#  'key_behavior_matrix_final_content_(1).docx.xlf',
#  '18_12_Gynaecologic_care_in_MSF_settings_(For_TWB_re-sent_28_Dec_2018).docx',
#  'GUIDANCE_FOR_STORYBOARD_AND_RELOCATION_FINAL.docx',
#  'Help_your_child_in_school.docx',
#  'Board_Member_Newsletter_Dec_17.docx',
#  'Security,_Health_and_Stress_in_the_Field.doc',
#  '9._Open_discussion_forum_-_consent_form_15.01.18.doc',
#  'Caring_for_child_survivors_of_sexual_abuse_training_-_final_evaluation.zip___SEP___CCS-Training-Final-Evaluation-Form.docx',
#  '20181011_info_Fr_(3).doc',
#  'OCHA_Onsite_Orientation_Guide_0104.docx',
#  '15.docx',
#  'Transforming_lives_through_the_gift_of_mobility.docx',
#  'Flyer_AMIF-ARCI_EN.docx',
#  'Prenatal_5_Select_pediatrician.docx',
#  'PED-B_LSS_S1_T1_Metabolismo.doc',
#  'IDP-17091_Worku_et_al_EN.docx',
#  'How_Google_Took_Over_the_Classroom.docx',
#  'Screening_forms.zip___SEP___12._SP-007-ET_Audiometry_Screening_final_v3.1_12Dec2018_Tracked_changes_(1).docx',
#  '04_Gallagher.docx',
#  'Final_agenda_doc.docx',
#  'Revised_Safety_and_Quality_Protocol_Final_at_September_2017.docx',
#  'SENS_Pre-Module_FULL_SENS_QUESTIONNAIRE_INSTRUCTIONS_v3_v30.07.2018_(1)_(2).docx',
#  'New-test.zip___SEP___Nicaragua_2_Accessible_seating_areas.docx',
#  'FGD_-_CB_Mechanisms,_Final_-_ENG.docx',
#  'Meet_the_trainers.docx',
#  '2018-PSP-Revision_MSF_Lab_Capacity.docx',
#  'Modelo_Desarrollo_-_Información_a_consultores.docx',
#  'Epidemiology_of_substance_use_among_forced_migrants_a_global_systematic_review.docx',
#  '201808_RA2017_-_08_RI_droits_des_femmes_FR.docx',
#  'DUMMY_word.doc',
#  'Final_Survey_Reminder_KO.docx',
#  'UMBURANAS_External_Evaluation_Mar_18_PRT_Part_3.docx',
#  'Proceso_Assessment_Diana_Final_(1)_(2a_parte).docx',
#  'lesson_7_The_American_flag.docx',
#  'Civics_(History_and_Government)_Questions_for_the_Naturalization_Test.docx',
#  '64_CICAD_SaionaraKR_EN.docx',
#  'ENAAT.odt',
#  'Communication_is_Aid_-_storyboard_FINAL_TEXT.docx',
#  'Module_8.zip___SEP___MHPSS_T4_tool2.docx',
#  'D._Cause_and_effect.docx',
#  'ISCG_HC_MSNA_Questionnaire_V4.docx',
#  'iACTfortra.zip___SEP___Community_Meeting_Guide_March_2017.docx',
#  '6._Traumatic_Stress_86-95.docx',
#  'Informe_Xarxa_Asil.cat_Dret_a_la_seguretat.doc',
#  'V1Cast_ACCD_Eldeutedecures(1).docx',
#  'Croatia.docx',
#  'Rapport_final-2.docx',
#  'Rencontres_Européennes_du_Socialo.zip___SEP___RES4.odt',
#  'AUGUST2018_Newsletter.docx',
#  'For_Translating-20180213T063321Z-001.zip___SEP___For_Translating___SEP___Playing_is_Learning_poem_Word.docx',
#  'Translators_without_borders_Document_2(1).docx',
#  'B._Case_File_Cover_Sheet.docx',
#  '10._University_in_Italy_(università).docx',
#  'IDP-17062_Gebreegziabher_et_al_EN.docx',
#  '2018-PSP-Revision_Operational_health_facilities_IDP_camps_V2.docx',
#  '2018-PSP-Revision-Food_security_assessment_Maiduguri_V2.docx',
#  'Bank_information.docx',
#  'حماية_ومسوولية_.docx',
#  '1._Handout_IYCF-E_Agenda_Example.docx',
#  'BIN_John_Edwards_Walking_Free_ENG.doc',
#  '10._Handout_Activity_Assessment_Timeline.docx',
#  'Perfil_profesional_Veterinario.pdf',
#  'WoA_2019_ENG.docx',
#  'Desk_Research_part.2_ita.docx',
#  'Text.docx',
#  'Fiche_de_poste_CDP_Algérie_FRà_traduire.docx',
#  'HRMI_Ambassador_Profiles_(TWB_Source_File).docx',
#  'Best_Friend_2018_draft_copy.docx',
#  'Table_213_figure_1.docx',
#  'GT03_FY19_Q1_Summary_SPA.DOC',
#  'CMZ_S4_T6_Escolas_ADPP.odt',
#  'Remerciements_2016_FR.docx',
#  'My_Special_Hair_-_text.doc',
#  '10_TEMPLATE_consent_form_mortality-survey_EN_v1.1_April_2017.doc',
#  'Psychosocial_base_training.docx',
#  'SERCOLDES_0717_20_Mon_and_Eval_Report_Part_4.docx',
#  '20180405_info_Fr.doc',
#  'Translate_to_Danish_Privacy_Policy.docx',
#  'Mortality_Survey_Template_v1.1_May_2017_Final.zip___SEP___Mortality_Survey_Template_v1.1_May_2017_Final___SEP___09_TEMPLATE_household_information_sheet_mortality-survey_EN_v1.1_April_2017.doc',
#  'Zika6.zip___SEP___Zika6___SEP___Mo_2016-Summary_JB.docx',
#  'When_should_I_call_the_police.docx',
#  'KII_-_Head_Teacher,_Final_-_ENG.docx',
#  '2._IRC-Girl_Shine_-_Part_3_-_Female_-_Sessions1-7_CR.docx',
#  'MyMatchday_Questionnaire_-_EN.DOCX',
#  'Day1_and_Day2_figures.docx',
#  'Partner_Grant_Agreement.docx',
#  '4th_P10_TibetGHP2_HL_EN.docx',
#  'Appendix_14_KENYA_VACS_QUESTIONNAIRE_MALE_CLEAN_FOR_TRANSLATION_15_AUG_2..._part_3.docx',
#  'CIEP_Narr_Report_0915_12__Part_4_SP.docx',
#  'IDP_18043_EN.docx',
#  'Interview_A25.docx',
#  'S.4.1_Resource_Mobilisation_3.6_version.docx',
#  'Human_rights_report_2016.docx',
#  'Know_More_Do_More_Menu.docx',
#  'MIC_S3_T1_Ciencia_verdade_certa.docx',
#  'Country_profiles_Egypt_UK_Germany_Russia.odt',
#  'HH_Trifold_Brochure_010517-v2_(003)__FINAL_(3).pdf',
#  'Facilitators_Guide_9_Nov.docx',
#  'ToR_PSNs_13_April_2018.docx',
#  'Pilot_Pyschosocial_Support_Application_(English).docx',
#  'IYCF-E_Follow_Up_Survey_Word_4192018_(1).docx',
#  'Gabon_Country_Report.docx',
#  'TS21-B_S3T4_Exploring_declaring_yourself.doc',
#  'Photo_Release_(OPTIONAL).doc',
#  'EDITED__Come_scrivere_una_Lettera_di_Presentazione_EN.docx',
#  'MSF_ERB_Approval_1755a_-_08_Nov_2017_(1).docx',
#  'menys_armes_nuclears.doc',
#  'Provisional_Workshop_Report.docx',
#  'Historia.docx',
#  'FACT-SHEET-Children-and-disclosure.-FINAL-.docx',
#  '2019_FAD_Patient_Charter_Letter_WG_VO1.docx',
#  'DISCUSSION_GUIDE_–_CYCLONE_EARLY_WARNING_PROCEDURES_-_ARC-TWB-BBCMA_updated_March_2019updated_February.docx',
#  'Ceméa_Suisse_Délégation_du_Tessin.docx',
#  'GBV_Briefing_Paper_for_translation_Part_2.docx',
#  'drive-download-20170908T073503Z-001.zip___SEP___Country_Strategic_Plan_Template_and_Guidance.docx',
#  '193_e_v100_child_protection_policy.docx',
#  'Membership_Criteria_(9).docx',
#  'translations.zip___SEP___Interview_with_Joachim_Ziert_from_NGO_15-09-2017.docx',
#  'Consent_Form_arabic.docx',
#  'EC_Letter_-_part_II.docx',
#  'english_script_for_voiceover.docx',
#  'Wally_the_Wave_new.docx',
#  'Petit_garçon_de_22_mois_atteint_6375.docx',
#  '14.docx',
#  'Naur_Longatunyo.pdf',
#  'two_docs.zip___SEP___Accepter_ses_limites_et_lâcher_prise_(1).docx',
#  'RTAfi_etudes.zip___SEP___FIetude19.odt',
#  'JD_template_14th_June2012.doc',
#  '14-Case-Management-Checklist.docx',
#  'MW-B_S2T4_Survival_fittest.doc',
#  'RTAfi_etudes.zip___SEP___FIetude3.odt',
#  'Collecting_quantitative_data_Step_2.3.docx',
#  'cccm.zip___SEP___1._Coordination_-_part_1_final.docx',
#  'EWM_Updates_Land_is_Life_Grassroots_Operations_&_Capacity_Partnerships_Brief_2017.docx',
#  '5._Welcome_to_Trócaire_Public_Engagement_2019.docx',
#  'Auto-Certification_Simplified_Chinese.docx',
#  'Fact_Sheet_-_Floorball_2016_Final.docx',
#  '4th_P14_IntroKathLausanneJB_HL_EN.docx',
#  'Rencontres_Européennes_du_Socialo.zip___SEP___RES5.odt',
#  'CODO_Medium_0518_12_SP__Part_10.docx',
#  'CBR_step_2.1_Introduction_to_the_week[1].docx',
#  '104_rs_55_csb_malawi_9NM.docx',
#  'A4_High_BMI_Leaflet.docx',
#  'Feed_672.docx',
#  'CoD.Seville_Agreement._Res_8.2005.docx',
#  'GT08_FY19_Q1_Summary_SPA.DOC',
#  'Fact-Sheet_Snakebites_August-2018.docx',
#  'Part_3_1439.doc',
#  '447_fa_59_CARE_Bangladesh_multi_sectoral_5NM.docx',
#  'Coffin_Siris_description.docx',
#  'IDP_17165_Chen_EN.docx',
#  "2018-PSP'Revision_Climate_and_Rainfall_Nigeria_V2.docx",
#  'Publisher_report_2016_final.docx',
#  'IlEtaitUneFoisTrad.docx',
#  'Bangladesh_handrub_EN.docx',
#  'Instructions-Leaflet2_ENglish_(2).docx',
#  'Hurricane_Maria_DR_427-18_IAP_#3.docx',
#  'KAP_survey_template_020715.zip___SEP___KAP_survey_template_020715___SEP___05_TEMPLATE_Data_Sharing_Agreement_MSF-OCA-2011.doc',
#  '1b_Improve_Learning_18-21.docx',
#  'WaSt_Policy_Brief-FINAL.docx',
#  'Trócaire_staff_survey.docx',
#  'LIT_Animal_relations_ENG.doc',
#  'Notice-from-Ukhiya-Magistrate_(1).docx',
#  '4)_Baruna_Red_Crescent_Society_Final.docx',
#  'OTC_deficiency_EN.docx',
#  '1.NIONG-projet-terrain_PROSSAN_ACF.docx',
#  'MEF2C_Haploinsufficiency_Syndrome_-_description.docx',
#  "Flash_-_21.09.17_-_Saudi_Arabia's_KSRelief_-_Cecilia_DANGELO-MARTINEZ.docx",
#  'IPC_Eval_form.doc',
#  '08_OSOCC_Guidelines.docx',
#  '2018_Task_02_Plague_Guidelines_Draft__Madagascar_algorithm_(1).docx',
#  '3._Membership_interest_response_email.docx',
#  'DAY_3_PGI_Foundation_training__Gender_GBV_Disability_Inclusion.docx',
#  '5._Data_protection_considerations.doc',
#  'Briefing_campaña_Unete__FINAL.docx',
#  'FAK_Tarana_Burke_ENG.doc',
#  'PDX_ProgramProfile.docx',
#  'Early_Learning_Final_(1)_Unicode.docx',
#  'LVL__MAC_NEEDS_TRANS.docx',
#  'TOP_Spec_2_HR_strategy_EN.doc',
#  'CURSO_Applic_for_Sementes_do_Sertão_PRT.pdf',
#  'Summaries_-_Jan_2019.zip___SEP___Summaries_-_Jan_2019___SEP___Brolin_Ribacke_2016.docx',
#  'MINUTA_PODER_ESPECIAL_PARA_ESTADOS_UNIDOS.docx',
#  '19_Phillips.docx',
#  '1118_Email_to_Guatemala.docx',
#  'Course_Evaluation_Form.docx',
#  'TALLER.docx',
#  'Senior_Solutions_2017_Barcelona.docx',
#  '2018-09-21_11-08-32_SkypeCall_youssouf.ambarka_djibril.bagayoko.docx',
#  'Windstorm_summaries_for_translation.zip___SEP___Windstorm_summaries_for_translation___SEP___Kouadio_2012.docx',
#  'ΤΟΜΕΑΣ_ΚΟΙΝΩΝΙΚΗΣ_ΠΡΟΝΟΙΑΣ_ΚΑΙ_ΚΑΤΑΣΤΑΣΕΙΣ_ΚΡΙΣΗΣ.doc',
#  'Short_descriptions_-_TM_Mirage_Rippling_GNE_myopathy.docx',
#  'ICO_Residency_Curriculum__Missed_Lines.docx',
#  'Rapport_Annuel_global_2017_Draft1_(1).docx',
#  'Potvrdenie_o_navsteve_lekara_Doctor_Visit.docx',
#  'Disabled_fans_experiences_v2.docx',
#  'Toolkit1.zip___SEP___3.1._Note_de_Cadrage_-_Documents_de_Référence.docx',
#  'S22_Family_Matters.docx',
#  'Traduccion_KKAWF-General_Information_ENG-MA_26022018.docx',
#  'WEEK_29_-_Healthy_MInds_F.doc',
#  '6._Delphi_method_study_-_participant_information_sheet_15.01.18.docx',
#  'BASIC_Etude_Café_Octobre_2018_FINAL_synthèse_25p.docx',
#  'Draft_2019_Survey_Email.docx',
#  'Manual_for_caseworkers-Socio-cultural_orientation_for_translation_into_EN.docx',
#  'Argumentaire_clientèle_luxe.docx',
#  'RTAfi_etudes.zip___SEP___FIetude2.odt',
#  'EvidenceAid_Water-faecal-pollution.zip___SEP___Oral_rehydration_salt_solution_for_treating_cholera_-_less_than_270_mOsmL_solutions_vs_more_than_310_mOsmL_solutions.docx',
#  'Learning_problems_in_children_of_refugee_background_a_systematic_review.docx',
#  'Flashcards_on_how_to_prepare_for_cyclones.docx',
#  'IDP_17012_Sun_EN.docx',
#  'Day_4_Quiz__3.6_Version.docx',
#  'Module_11_2018.docx',
#  'Appendix_14_KENYA_VACS_QUESTIONNAIRE_MALE_CLEAN_FOR_TRANSLATION_15_AUG_2..._part_2.docx',
#  'Session_Plan_Group_Work_-_Case_Studies.docx',
#  'CLAN_Leaflet.pdf',
#  'EBOLA_script_for_translation.docx',
#  'Physical_interventions_to_interrupt_or_reduce_the_spread_of_respiratory_viruses.docx',
#  'one_pager_feedback_report_country_consultation_participants_adults.docx',
#  'DOS_SOLTHIS_2019-2021.docx',
#  'Exit_Survey_Cameroon.zip___SEP___IMG_20171027_0012.pdf',
#  'PPI_Rebranding_Announcement_Final.docx',
#  'Country_Medical_evacuation_plan.docx',
#  'Tier2-Module4-Knowledge-Questions.docx',
#  'Madagascar_NHRI_HRC_120.docx',
#  'Photography_Guide_pdf.docx',
#  'IMS_6.zip___SEP___39._Caliya_Cagabaruur.docx',
#  'rkm-article_AMIF-ARCI_(German).docx',
#  'A_systematic_review_of_the_mental_health_impacts_of_sport_and_physical_activity_programmes_for_adolescents_in_post_conflict_settings.docx',
#  'LAN1_S1_T2_Bantu_Africa.doc',
#  'Improving_Adolescent_Sexual_and_Reproductive_Health_-_A_Systematic_Review_of_Potential_Interventions.docx',
#  '2017_PMTCT_handout_Final_version_for_PAO_(1).docx',
#  'La_violencia_machista_sigue_siendo_un_desafío_para_Honduras_según_una_activista_3_8_2016.docx',
#  '201702_Letter_from_the_NGO_Committee_on_Migration.docx',
#  '20170720_Abolition_newsletter_part_2.docx',
#  'Now_that_you_have_access_to_healthcare.docx',
#  '63_Lewis.docx',
#  'Module_22.docx',
#  'Landing_page.docx',
#  'Atrapalo_y_Fundacion_Montblanc.docx',
#  '35._SHUKRI_BAANDARE.docx',
#  'SEC_simulation_-_school_case_studies.docx',
#  'FireSafety_2019_PT-mz.docx',
#  '2017_WBW_LOGO___EXPLANATION_-_Text_Only.doc',
#  'December_Newsletter.docx',
#  'Formularios.docx',
#  'Chlorpromazine_versus_placebo_for_schizophrenia.docx',
#  '2018_call_for_applications.docx',
#  '1d_Where_we_work_LTU.docx',
#  'FWM_Wheelchair_Provision_Standards.docx',
#  'CLAC_project_portfolio_2018.docx',
#  'What_Matters_Issue_11_for_translation.docx',
#  'NonDiscriminationAntiHarassment_Policy.docx',
#  'Algeria_Country_Report.docx',
#  'For_Translating-20180213T063321Z-001.zip___SEP___For_Translating___SEP___ED_Pond_Observation_Checklist_03_2017_Word.docx',
#  'trascrizione_video_seconda_parte.docx',
#  'HEAT Antenatal Care (part two) 14_JL.docx',
#  '20._Handout_Participant_Blank_Action_Plan.docx',
#  'GoodBirth_Newsletter_2018-05_text_for_translation.docx',
#  'Les_quatre_talents_mal_aimés_des_managers_et_des_organisations.docx',
#  'Nutrition_summaries_for_Spanish_translation.zip___SEP___Nutrition_summaries_for_Spanish_translation___SEP___Barros_2016_.docx',
#  'Key_info.docx',
#  '1109_NEAR_Follow_up_email_to_Wendy_and_Guido.docx',
#  'Topical_silver_for_preventing_wound_infection.docx',
#  'TWB_Tripoli_Arabic_2_(1).docx',
#  'HEAT_Water_1.docx',
#  'REACH_BGD_JENA_C26_BT_M_3.docx',
#  'Proposition_de_projet_2019-2021_VF.docx',
#  'Lage_multi-annual_application_2018_SP_Part_4.docx',
#  'Sept17_Newsletter.docx',
#  'Parent_Consent_Form_for_Media_Recording.docx',
#  'ToolSheet1_DevelopingIndividualSecurityAwareness.docx',
#  'Diptheria_Campaign_-_WHO.docx',
#  'DREAM_Marketing_&_Procedures_ENG_Final.docx',
#  'Disponibilisation_terrain.pdf',
#  "Note_à_l'attention_des_directeurs_pour_roles_des_IRP.docx",
#  'Feeding_the_child_during_and_after_illness-2columns.docx',
#  'WEEK_3_-_Amazing_Daisy.docx',
#  '5.2_Public_Income.docx',
#  'RTAfi_etudes.zip___SEP___FIetude7.odt',
#  'infographic_main.docx',
#  "Rapport_d'activite_Ecole_des_Femmes.docx",
#  'EST-Maris_Sander-webstory-Ali-Baba-eng_CB_FINAL.doc',
#  'Consent_to_Treatment_form.docx',
#  '2018.09.06_INEE_ALC_brief.docx',
#  'Venue_announcement_article_v2.docx',
#  '20191004_APV_Liangwu.docx',
#  'Appendices.doc',
#  '16._CAASHO_KABLOW.docx',
#  'Recommendations_for_Comprehensive_Post.docx',
#  'NEX9_HKI_NE_Art_role_des_EDM_AGRANDIS_Aout_17.docx',
#  'Bone_grafts_and_bone_substitutes_for_treating_distal_radial_fractures_in_adults.docx',
#  'importanttranslationforpleaguetreatmentcenterin.zip___SEP___2_SOP_Dressing_in_PPE_-_IPC_-_Copy.docx',
#  'Infant_and_Young_Child_Feeding_in_Emergencies_Training_-_Application_(Middle_East_2017).docx',
#  'Healthcare_jobs.docx',
#  '145_fa_55_multi_ethiopia_6NM.docx',
#  'SmartSmile_One-pager.docx',
#  'TS21-B_S3T1_Teacher_politics_ethics.docx',
#  'Lativa_-_PSP_(1).docx',
#  'Wasserkraftwerk_rumänische_Karpaten.docx',
#  '01_IFRC_Guidelines_to_Hygiene_Promotion_in_Emergencies_-_final_version.docx',
#  'EvidenceAid_Water-faecal-pollution.zip___SEP___Antiamoebic_drugs_for_treating_amoebic_colitis.docx',
#  'Front-Page-v7-1_pdf_without_click_on_link.docx',
#  'ফ্লাশকার্ড_ব্যবহারের_নিয়মাবলি.docx',
#  'Thematic_Paper.docx',
#  '32._FAHIIMA_QUUJE.docx',
#  'Slovenia.docx',
#  '20190110_info_Fr.docx',
#  'Itineraire_Trad.docx',
#  '2016_October_Budapest_Agenda.docx',
#  'Safe_and_Well_Language.docx',
#  'Ophthalmic_Operating_Theatre_Practice_final_NORMAL_(1).docx',
#  'PDX_PHS_Letter_Kelly.docx',
#  '2._Who_We_Are.docx',
#  'cccm.zip___SEP___Audio_module_3_(video).docx',
#  'Understanding_CD4_Cells_and_CD4_Cell_Tests_for_translation.docx',
#  'Amref_Lof_Magazine_vertaling.docx',
#  'Networking_events.docx',
#  'IDOP-D-17-00191_Abstract_EN.docx',
#  'For_copy-editing_Syria_-_Evacuation_Story_-_SR_111018.docx',
#  'Template_Letter_Insurance_Preauthorization.docx',
#  'UMBURANAS_Medium_Part_7__PORT.docx',
#  '2Nutrition_summaries_for_translation.zip___SEP___2Nutrition_summaries_for_translation___SEP___Nkonki_2017.docx',
#  'Libya_Narrative.docx',
#  'Courrier_partenaires_coupes_et_reports_final_(002).docx',
#  'REPONGAC.docx',
#  '2_CRC_for_translation.docx',
#  'Constitution_for_The_Rosetta_Foundation_20170522.docx',
#  'DRA_Wohnboxen_Arme.docx',
#  'The_australian_war_memorial.doc',
#  'Prophylactic_antibiotics_for_penetrating_abdominal_trauma.docx',
#  '10-11_General-information-about-the-advent-calendar-e.g.-duration.doc',
#  'Expodefensa.odt',
#  'test.txt',
#  'declaracion_de_informe_fina_(1).pdf',
#  '2Nutrition_summaries_for_translation.zip___SEP___2Nutrition_summaries_for_translation___SEP___Galvao_2013.docx',
#  'FASOL2012-2013Part2.docx',
#  'Balises_études_de_cas_CETRI_VD.docx',
#  'IDP_16300_Cui_EN.docx',
#  'Copy_of_New_Interview_Research_Consent_form_HEALTH_PROFS.docx',
#  '20957ACF_Booklet_cauchemars_EN.docx',
#  'Demographic_Data_Teachers_PR_TPD_RD_July18.docx',
#  'Supervisory_review_appeal-2017-Farmonov.docx',
#  'Windstorm_summaries_for_translation.zip___SEP___Windstorm_summaries_for_translation___SEP___Zhang_2016.docx',
#  'Aide_mémoire_brut_traduction.docx',
#  'Common_variable_immune_deficiency_disease_description.docx',
#  'PSP_Stress_Counsellor_Network_2013.docx',
#  '210_fa_56_tech_RRT_article_10NM_amended_clean.docx',
#  'HRMI_EN-ES.docx',
#  '2._CCCM_framework_and_national_authorities_(final).doc',
#  'Nutrition_summaries_for_Spanish_translation.zip___SEP___Nutrition_summaries_for_Spanish_translation___SEP___Muscaritoli_2017.docx',
#  'Session_Plan_-_Cholera_and_IYCF_BR.docx',
#  '2018-038.Conférence.Les_Petits_Frères_des_Pauvres_Michel.docx',
#  'semaine_de_la_communion_2018.docx',
#  'Informe_DDHH_2017_(parte_8).doc',
#  'Country_hibernation_plan.docx',
#  '2._CAASHA_SHAACUUR_-_Question_(3).docx',
#  'KCNB1.docx',
#  '201806_stigma_rec_media_ES_(1).docx',
#  'Adult_education_-_how_to_go_back_to_school.docx',
#  'E-Cubed_FAQs_(For_Translation).docx',
#  '101_fa_55_livingfarms_India_16NM.docx',
#  '1.4_Annuncio_di_lavoro_falso_o_annuncio_truffa.docx',
#  'Informe_DDHH_2017_(parte_10).doc',
#  'EditNewNR_Indicators_Manual_version_260318_(comments_integrated).docx',
#  'IDOP-D-17-00229_Abstract_EN.docx',
#  'START.zip___SEP___START___SEP___MediaAdvocacy___SEP___Start.MA.PowerPoint.pdf',
#  'Colombia_militarisation_after_the_peace_agreements.docx',
#  'IYCF-E_Welcome_Packet_Template.doc',
#  'Caregivers__Co-Creation_Session_Guide.docx',
#  'Zika3.zip___SEP___Zika3___SEP___Citil-Dogan_2016-Zika_SR_JB_SL.docx',
#  'Statement_of_support_2018_Final.docx',
#  '4._Session_Plan_Global_IYCF-E_Documentation.docx',
#  '1._Invitation_to_the_Buddy_Initiative_2018_emails_1-5_for_TWB_translation.docx',
#  '2017_WBW_-_ACTION_FOLDER_-x-_Insert_(1).docx',
#  'Annex_1_Hazard_Assessment_Template.docx',
#  'articla_a_traduire_3.docx',
#  'Adult_education.docx',
#  'Survey_Oxfam_Project_1_for_feedback_9-11-18.docx',
#  'REACH_BGD_JENA_C26_BT_M_1.docx',
#  'Module_18.docx',
#  'Anlage_1_Hinweise_zur_Projektanmeldung_�ber_das_Antragsportal_.pdf',
#  'ENN.zip___SEP___ENN___SEP___221_fa_55_assessment_Scott_7_NM_amended_clean.docx',
#  'High_literacy_participant_handbook_-_graphs_and_diagrams_to_be_translated.docx',
#  'Website_supporter_page_and_heading_terms_for_translation.docx',
#  'cash_transfers_-_210217.docx',
#  '8_Child_Survivor_Initiative_-_KAP_Survey_-_PLAN2_(H).docx',
#  'regresion_tumoral_testicular_espontanea_ecancer_corregido3_ecms3067_(1).docx',
#  '17074_IDP_Cai_EN.docx',
#  '11._Handout_Activity_Indicators.docx',
#  'JILKA_1AAD_.docx',
#  "4_L'architecte.docx",
#  'Mortality_Survey_Template_v1.1_May_2017_Final.zip___SEP___Mortality_Survey_Template_v1.1_May_2017_Final___SEP___08_Random_Number_Table_EN_v1.1_April_2017.pdf',
#  'TableTopScenarioLearning_050417.docx',
#  'Rift_Valley_Fever_Questions.docx',
#  'Guide_to_humanitarian_interpreting_&_cultural_mediation.docx',
#  'Resettlement.docx',
#  'FRR_Workbook_2014_updatedMarch2018.docx',
#  'Exit_Survey_Cameroon.zip___SEP___IMG_20171026_0022.pdf',
#  'Updates_CBHFA_flip_chart_draft_EN_editid.docx',
#  'Gamayun_WFP_EN-AR_revision.docx',
#  'Non-citizen_Assistance_-_Agreement.doc',
#  'Nuevo_consentimiento.doc',
#  '7_2019_Horse.docx',
#  'Our_Story_with_ANE.docx',
#  'GO_Campaign_Baseline_Data_Survey_2017_ParuParu.docx',
#  '2018-PSP-Revision_UNFPA_SRH_assessment.docx',
#  '2015_03_Wasserverbrauch_Fairtrade-Rosen_Massai.docx',
#  'IDOP-D-18-00312_Abstract_EN.docx',
#  '第二部分_医疗记录.docx',
#  'FRR_Session_8__Manual_CSAs_and_Promos_2014v2.docx',
#  'Vollzug_Handelsregister_14.08.2017.pdf',
#  'Sahalava__Medium_Single_Year_Proposal_FR_Part_6.docx',
#  '2018-PSP-Revision_Aljazeera_NEWS_NIGERIA_BH_attack_Banki.docx',
#  'AVIN001-2016-ForTranslationSpToEng_-justtext.docx',
#  'cafetranslations.zip___SEP___How_to_recruit_a_Disability_Access_Officer_v2.docx',
#  'Tsunami_messages-_What_to_do.docx',
#  'Uzbekistan_Country_Report.docx',
#  'CP_-_Lancement_public_rapport_091118_-_For_Translation.docx',
#  'Share_your_View_Poster_4_May_2018.doc',
#  'finaleltern.doc',
#  'Cat.docx',
#  'PAPE_FINAL_FOR_TRANSLATION.docx',
#  'IFRC.EPoA_PLANNING_template_16_Sept_2013_(1).docx',
#  'Mission_Rohingyas_témoignage_Hamas_RÉV.docx',
#  'GC21.docx',
#  '3._National_System_of_civil_protection.doc',
#  'VOCIARE_1-LUGLIO.docx',
#  '190429_Spanish_Parliament_hearing.docx',
#  'Summaries_for_translation.zip___SEP___Summaries_for_translation___SEP___Ercole_2014.docx',
#  'A3_Annual_Programme_Report_User_guide.docx',
#  'S.2.2_Inject_A_PoA___3.6_version.docx',
#  'BA_Cameroon.zip___SEP___IMG_20171026_0006.pdf',
#  'Module_12_recreate.docx',
#  'FB-Posts.docx',
#  'Introduzione.docx',
#  '2018-PSP-Revision_EPI_results_V2.docx',
#  'HFCP_Unit_1_update_August28.docx',
#  'column_a.docx',
#  'CSC_Research_Forum_-_ToR.docx',
#  'When_to_Start_Your_Childs_Solid_Foods-2columns.docx',
#  'Charge_de_travail.docx',
#  'Hola_MSA_ES.docx',
#  'OptimiserLesRéunionsTraduction.docx',
#  'Residency_Curriculum_Section_II,_Very_Advanced_Level__Subspecialist.docx',
#  'Module_10.zip___SEP___eCBHFA_Healthy_Lifestyles_&_Youth_Introduction.docx',
#  'War_Child_extra_questions_TA.docx',
#  'PPI_New_Methodology_Website_FAQs_Final.docx',
#  'Tool_Quality_of_Participation_Questionnaire.docx',
#  'Interventions_for_preventing_injuries_in_problem_drinkers.docx',
#  'M._24_THEORIES_OF_CHANGE.docx',
#  'Windstorm_summaries_for_translation.zip___SEP___Windstorm_summaries_for_translation___SEP___Ahmed_2016.docx',
#  'A_Domain_French_Version_-_for_checking_French_version_of_the_user_commands_(see_screenshots).zip___SEP___A2_French.docx',
#  '417_rs_59_micronutrient_powder_distribution_cambodia_3NM.docx',
#  '29_Obstetrics_maternal_referral_criteria.docx',
#  'AMR(1)_(1).docx',
#  'LAN2_S1_T1_Introducao_modulo.docx',
#  'Intermittent_iron_supplementation_for_improving_nutrition_and_development_in_children_under_12_years_of_age.docx',
#  'Cuadernillo_general__correcciones_(002).docx',
#  'PGI_-_Wash_QS_with_camp_details.docx',
#  'Organisation_Nigérienne_pour_la_Promotion_et_la_Prime_Enfance.docx',
#  'Introduction_to_GCLP_Final._27-05-15.docx',
#  'Lessons_4-5-6.zip___SEP___LESSON_6_-_Post-Surgery_Diet_Final_STBrand_26JUN2018.docx',
#  'OCHA_and_the_Humanitarian_Programme_Cycle.doc',
#  '2019-01_TWB_blog_-_Language_in_education.docx',
#  'Nutrition_summaries_for_Spanish_translation.zip___SEP___Nutrition_summaries_for_Spanish_translation___SEP___Ramakrishnan_2009.docx',
#  'présentation_de_pratiques.docx',
#  'banner_for_health_awareness_campaign.docx',
#  'Note_Taking_Head_Teachers_PR_TPD_RD_July18.docx',
#  'Sliding_Fee_Schedule_2018_for_translation.docx',
#  'Lip_repair_01_Learn_about_lip_repair.docx',
#  '4._20170123_MSF_the_next_steps_in_movement_evolution_Debate_Outline.docx',
#  '1Refugee_Collection.zip___SEP___Assessing_trauma_and_mental_health_in_refugee_children_and_youth_a_systematic_review_of_validated_screening_and_measurement_tools.docx',
#  'translations.zip___SEP___Response_from_Rollwagerl_93_eV_-_English_translation.docx',
#  'Over_het_Rode_Kruis_Suriname,_Hazard_part.docx',
#  'Statement_ECOSOC_-_Povert_Eradication_2017.docx',
#  'Procédure_personnalisée_trad2a.docx',
#  'Zinc_supplementation_as_an_adjunct_to_antibiotics_in_the_treatment_of_pneumonia_in_children_2_to_59_months_of_age.docx',
#  'Notice-from-Ukhiya-Magistrate.docx',
#  'PCA_S6_T3_Educacao_distancia.doc',
#  'Short_Survey_on_safeguarding_and_sexual_misconduct_in_Oxfam.docx',
#  'Direct_action_against_arms_fairs_in_New_Zealand_and_South_Korea.odt',
#  "REU_Rio's_homeless_ENG.doc",
#  'RELATÓRIO_DE_AVALIAÇÃO_2016_E_PLANEJAMENTO_2017_Part_4.docx',
#  'Session_2_Manual_-_Phases_of_Disaster_and_Critical_Information__2014v2.docx',
#  'Corticosteroids_for_treating_dengue_shock_syndrome.docx',
#  'IDP_16297_Ge_EN.docx',
#  'Snowball_Referral_Email_Text.docx',
#  'Traduc_1_Textos_Memoria_OID_2017.docx',
#  '3.2_Triangulating_evidence[1].docx',
#  'Communication_essentials_in_public_health_for_Member_States.docx',
#  'Child_protection_ed.docx',
#  '1910-GreekMedia-Baz-Final_Arabic.docx',
#  'SP-003-ET_-_Visual_Acuity_Screening.docx',
#  'ziptest.zip___SEP___6_things_to_know_about_humanitarian_rules_on_sex.docx',
#  '830_fa_52_GNC_Yemen_6_FINALNMCOPY.docx',
#  'Procédure_personnalisée_trad2b.docx',
#  'WASH_MESSAGES__FOR_TRANSLATION_(5).docx',
#  'IM_Life_Skill_level_1_and_2_V1_Weeks_1-2.docx',
#  '201_fa_56_turkey_13_NickNM.docx',
#  '201702_Tercer_sector_raices_ES_V1.docx',
#  'R2.3.1_Logframe_Component_cards.doc',
#  'National_Staff__Checklist_-_leaving.doc',
#  'WEI_Advocacy_Guide_-_Part_9_for_Translation.docx',
#  'Adult_Education_Resident_Flyer_March_2018.docx',
#  '01_To_be_reviewed_by_ST_partner.zip___SEP___CP_SPEECH_0-12_mos_03_To_expose_baby_to_key_sounds_as_much_as_possible.docx',
#  '2._CM_TOR_final.doc',
#  'Inviting_all_organisation_to_ERN.docx',
#  'Combined_psychological_and_pharmacological_interventions.docx',
#  'Journal_Charges_webpage.docx',
#  'LUL_Language_and_the_patriarchy_SERBIAN_NEEDS_TRANS.doc',
#  'MEG_Homeless_Camps_and_fire_codes_ENG.doc',
#  'Base_hibernation_plan-ENàtraduire.docx',
#  'NIONG_AFD_Asmae_Liban_pour_traduction.docx',
#  'Potvrdenie_o_navsteve_lekara_Doctor_Visit.docx.xlf',
#  'Ops_Guidance_2017_v_3_FINAL_COPY_WORD_VERSION_for_translation_ARABIC.docx',
#  'ICOIntlGuidelinesforAccreditation-Spanish.docx',
#  'TIC_S2_T3_Comunicacao.docx',
#  '203_fa_55_afghanistan_16_to_NickNM.docx',
#  'Module_5.docx',
#  'Windstorm_summaries_for_translation.zip___SEP___Windstorm_summaries_for_translation___SEP___Abdo_2016.docx',
#  'CEPA_0417_05_SALESFORCE_Final_Rpt_PRT_Section_4.docx',
#  'PCI_Evaluation_Form.docx',
#  'IDP-16328_Tadesse_et_al_EN.docx',
#  'A3_Anual_Programme_Report_User_Guide.docx',
#  'Evidence_Aid_Neonatal_Health.zip___SEP___Dilute_versus_full_strength_formula_in_exclusively_formula_fed_preterm_or_low_birth_weight_infants.docx',
#  'NEX9_NIGER_husband_schools_FINAL.DOCX',
#  'Disponibilidad_de_terrenos_FRANCÉS.pdf',
#  'ziptest.zip___SEP___Financial_Fitness_with_Budgeting_on_a_Fixed_Income.docx',
#  "NE.4_Avenant,_ANO_et_information_à_l'AFD.docx",
#  'bilancio_2016.docx',
#  'Windstorm_summaries_for_translation.zip___SEP___Windstorm_summaries_for_translation___SEP___Shipp_Hilts_2016.docx',
#  'Laundry.doc',
#  'The_Impact_of_Detention_on_the_Health_of_Asylum_Seekers.docx',
#  'IPS_Rebutting_deniers_and_wafflers_ENG.doc',
#  'Privacy_Practices_(1).pdf',
#  'CIEP_Medium_0518_09__SP__Part_6.docx',
#  'Diabetes-Team-Education.docx',
#  '2019_6_AGOA_CEI_0006_Livelihoods_(003).docx',
#  'Sao_Tome_And_Principe_Country_Report.docx',
#  'December_bulletin.docx',
#  'ESPpratiquePART2.docx',
#  'Pill_14.2__Emociones.docx',
#  'SOPPharma_MOD2Les_étapes_clés....docx',
#  'Protocol_II_Technical_Maintenance_-_Sonosite_Micromax_and_MTurbo_ultrasound.docx',
#  'Fibrodysplasia_ossificans_progressiva_disease_description.docx',
#  'Know_your_rights_as_an_immigrant.docx',
#  'Legalisation_of_Stay_for_non_EU_students.docx',
#  'El_fantasma_de_Canterville_solución.doc',
#  'Latvia_Buddy_Survey_RAS_End_Point_Updated_for_tra.docx',
#  'BASIC_FOOT_ASSESSMENT_CHECKLIST.docx',
#  'PSSiE_working-in-stressful-si_EN.docx',
#  'Nota_CSFD_Nov_2018_ES_.docx',
#  'Doc_traduction_ESSENTIAL_TOOLS_justtext.doc',
#  'Nurses_experiences_of_ethical_preparedness_for_public_health_emergencies_and_healthcare_disasters.docx',
#  'FOND971-2016SpanishRecipient_-_justtext.docx',
#  '2018-PSP-Revision_Travel_permit.docx',
#  'Evaluation_form_Management_session_ENG_v2_2016.docx',
#  '25.09.2018_Artigo_Emprego_Apoiado_Flavio_Gonzalez.docx',
#  'Guidelines-_Large_Development_Grant_EN.docx',
#  'endTB_interim_v04.docx',
#  'Audio_module_0_Intruduction_to_the_course_(video).docx',
#  '151_fa_51_SUN_Pakistan_11_FINALCOPYFMNMN.docx',
#  'National_Staff_Performance_Appraisal.doc',
#  'AFD_Asmae_Liban_VF_pour_traduction_anglaise_part_2.docx',
#  'International_Website_Content_Translation_PART_4_PORTUGUESE_(1).DOCX',
#  'Capitolo_8.docx',
#  'WORKING_IN_GREECE_EN.docx',
#  'Module_11.docx',
#  'Notice_Privacy_Practices_English.docx',
#  'PED-B_BIP_S3_T1_Esperanca_fe_coragem.docx',
#  'OCHA_Tip_Sheet_Reflecting_Community_Engagement_in_HRPs.docx',
#  'Anlage_4_Handreichung_Sonderinitiative_Flucht_(SI_Flucht).pdf',
#  'Draft_Regional_Action_Plan.docx',
#  'National_Staff_Request_for_Extension.doc',
#  'CESCR_-_report_on_France_ETOs_and_private_education_v3_(2).docx',
#  'Balance_for_Better__Collaboration_for_gender_equality.docx',
#  'JILKA_3AAD.DOCX',
#  '_Flowers_Newsletter_October_2018.docx',
#  'wiki.zip___SEP___wiki1.docx',
#  'Liberia_-_KEEP_story_edited_SR_240119_FINAL.docx',
#  'Validate_your_educational_diplomas.docx',
#  'IFRC._Working_Advances_to_National_Societies.Finance_036.2008.docx',
#  'OpenWHO-about-us.docx',
#  ...]
