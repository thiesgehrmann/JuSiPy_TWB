# %% [markdown]
# # Library and Data Preparation

# %%
import os
import fnmatch
import TWB.xliff as xliff
import spacy
import pandas as pd
import queue
import numpy as np
import unicodedata

# %%
# normalize unicode characters
def NFD(s):
        return unicodedata.normalize('NFD', s)

# put your data path here
#data_dir = os.getcwd()
data_dir = '/home/mixalis/Downloads/Translators Without Borders/'
metadata = pd.read_excel(data_dir + 'Hackathon-for-Good-2019_TWB-Challenge_Metadata.xlsx')

# choose only text documents
#accepted_documents = metadata.loc[(metadata['Format'] == 'doc') | (metadata['Format'] == 'pdf')].drop_duplicates()

# fix some problems with the encoding of special characters in filenames
#accepted_documents['Filename'] = accepted_documents['Filename'].apply(NFD)
# we use all documents after all
metadata['Filename'] = metadata['Filename'].apply(NFD)

# update data path with the sdlxliff directory
data_dir += '/hackathon-for-good-2019_TWB-challenge_files/'

# %%
metadata
# Out:
#                      Date  Wordcount  \
# 0     2016-12-12 00:56:11      109.0
# 1     2016-12-12 01:53:23      121.0
# 2     2016-12-12 09:30:28      109.0
# 3     2016-12-12 12:57:12      121.0
# 4     2016-12-12 19:04:04    45371.3
# 5     2016-12-12 19:04:04    45371.3
# 6     2016-12-12 19:04:04    45371.3
# 7     2016-12-12 19:04:04    45371.3
# 8     2016-12-12 19:04:04    45371.3
# 9     2016-12-12 19:04:04    45371.3
# 10    2016-12-12 19:04:04    45371.3
# 11    2016-12-12 19:04:04    45371.3
# 12    2016-12-12 19:04:04    45371.3
# 13    2016-12-19 11:04:31        0.0
# 14    2016-12-19 12:09:22      109.0
# 15    2016-12-19 12:10:10      109.0
# 16    2016-12-26 11:23:43    13295.9
# 17    2016-12-26 11:23:43    13295.9
# 18    2016-12-26 11:23:43    13295.9
# 19    2016-12-26 11:23:43    13295.9
# 20    2016-12-26 11:23:43    13295.9
# 21    2016-12-26 11:23:43    13295.9
# 22    2016-12-26 11:23:43    13295.9
# 23    2017-01-04 08:20:01     1041.0
# 24    2017-01-16 15:35:52     2703.2
# 25    2017-01-16 15:35:52     2703.2
# 26    2017-01-16 15:35:52     2703.2
# 27    2017-01-16 15:35:52     2703.2
# 28    2017-01-16 15:35:52     2703.2
# 29    2017-01-16 15:35:52     2703.2
# ...                   ...        ...
# 34519 2019-05-20 00:05:14      439.0
# 34520 2019-05-20 00:11:21      439.0
# 34521 2019-05-20 00:12:30      289.0
# 34522 2019-05-20 09:13:48      866.5
# 34523 2019-05-20 09:13:48      866.5
# 34524 2019-05-20 09:52:02      439.0
# 34525 2019-05-20 09:53:30      289.0
# 34526 2019-05-20 09:54:35     1149.0
# 34527 2019-05-20 09:54:35     1149.0
# 34528 2019-05-20 10:02:41     1074.0
# 34529 2019-05-20 10:02:41     1074.0
# 34530 2019-05-20 10:10:06      324.0
# 34531 2019-05-20 11:51:28     2872.4
# 34532 2019-05-20 13:22:18     1670.3
# 34533 2019-05-20 15:22:33      680.8
# 34534 2019-05-20 15:22:33      680.8
# 34535 2019-05-20 15:22:33      680.8
# 34536 2019-05-20 15:22:33      680.8
# 34537 2019-05-20 15:22:33      680.8
# 34538 2019-05-20 15:22:33      680.8
# 34539 2019-05-20 15:22:33      680.8
# 34540 2019-05-20 15:22:33      680.8
# 34541 2019-05-20 15:22:33      680.8
# 34542 2019-05-20 15:22:33      680.8
# 34543 2019-05-20 15:22:33      680.8
# 34544 2019-05-20 15:22:33      680.8
# 34545 2019-05-20 15:22:33      680.8
# 34546 2019-05-20 15:22:33      680.8
# 34547 2019-05-20 15:22:33      680.8
# 34548 2019-05-20 15:22:33      680.8
#
#                                                 Filename Source_lang  \
# 0                                          347words.docx          en
# 1                                          387words.docx          en
# 2                                          347words.docx          en
# 3                                          387words.docx          en
# 4                                  gtr_charts_FINAL.PPTX          en
# 5                                  gtr_charts_FINAL.PPTX          en
# 6                                  gtr_charts_FINAL.PPTX          en
# 7                                  gtr_graphs_FINAL.XLSX          en
# 8                                  gtr_graphs_FINAL.XLSX          en
# 9                                  gtr_graphs_FINAL.XLSX          en
# 10     Global_Tools_Review_FINAL_Nov2016_graphs_corre...          en
# 11     Global_Tools_Review_FINAL_Nov2016_graphs_corre...          en
# 12     Global_Tools_Review_FINAL_Nov2016_graphs_corre...          en
# 13                                         347words.docx          en
# 14                                         347words.docx          en
# 15                                         347words.docx          en
# 16     DRAFT_REACH_HTI_Multisector_Assessment_in_Sud_...          en
# 17     DRAFT_REACH_HTI_Multisector_Assessment_in_Sud_...          en
# 18     DRAFT_REACH_HTI_Multisector_Assessment_in_Sud_...          en
# 19     DRAFT_REACH_HTI_Multisector_Assessment_in_Sud_...          en
# 20     DRAFT_REACH_HTI_Multisector_Assessment_in_Sud_...          en
# 21     DRAFT_REACH_HTI_Multisector_Assessment_in_Sud_...          en
# 22     DRAFT_REACH_HTI_Multisector_Assessment_in_Sud_...          en
# 23                            Executive_Summary_ENG.docx          en
# 24     What_Now_-_Key_Messages_for_translation_-_Duri...          en
# 25     What_Now_-_Key_Messages_for_translation_-_Duri...          en
# 26     What_Now_-_Key_Messages_for_translation_-_Duri...          en
# 27     What_Now_-_Key_Messages_for_translation_-_Duri...          en
# 28     What_Now_-_Key_Messages_for_translation_-_Duri...          en
# 29     What_Now_-_Key_Messages_for_translation_-_Duri...          en
# ...                                                  ...         ...
# 34519                       REACH_BGD_JENA_C26_RI_F.docx          bn
# 34520                       REACH_BGD_JENA_C26_RI_F.docx          bn
# 34521                       REACH_BGD_JENA_C26_RI_M.docx          bn
# 34522                 TWB_OnlineSurvey-Final_190520.docx          en
# 34523                 TWB_OnlineSurvey-Final_190520.docx          en
# 34524                       REACH_BGD_JENA_C26_RI_F.docx          bn
# 34525                       REACH_BGD_JENA_C26_RI_M.docx          bn
# 34526                      REACH_BGD_JENA_C5_BT_F_1.docx          bn
# 34527                      REACH_BGD_JENA_C5_BT_F_1.docx          bn
# 34528                      REACH_BGD_JENA_C5_BT_F_2.docx          bn
# 34529                      REACH_BGD_JENA_C5_BT_F_2.docx          bn
# 34530                      REACH_BGD_JENA_C5_BT_M_1.docx          bn
# 34531        2019_05_05NPF_Narrative_Proposal_NN_vn.docx          en
# 34532                            START_Presentation.pptx          en
# 34533             Patient_Release_Form_-_Final_4.25.docx          en
# 34534             Patient_Release_Form_-_Final_4.25.docx          en
# 34535             Patient_Release_Form_-_Final_4.25.docx          en
# 34536             Patient_Release_Form_-_Final_4.25.docx          en
# 34537             Patient_Release_Form_-_Final_4.25.docx          en
# 34538             Patient_Release_Form_-_Final_4.25.docx          en
# 34539             Patient_Release_Form_-_Final_4.25.docx          en
# 34540             Patient_Release_Form_-_Final_4.25.docx          en
# 34541             Patient_Release_Form_-_Final_4.25.docx          en
# 34542             Patient_Release_Form_-_Final_4.25.docx          en
# 34543             Patient_Release_Form_-_Final_4.25.docx          en
# 34544             Patient_Release_Form_-_Final_4.25.docx          en
# 34545             Patient_Release_Form_-_Final_4.25.docx          en
# 34546             Patient_Release_Form_-_Final_4.25.docx          en
# 34547             Patient_Release_Form_-_Final_4.25.docx          en
# 34548             Patient_Release_Form_-_Final_4.25.docx          en
#
#       Source_country Target_lang Target_country                          NGO  \
# 0                 US          fr             FR            British Red Cross
# 1                 US          fr             FR  Translators without Borders
# 2                 US          fr             FR            British Red Cross
# 3                 US          fr             FR            British Red Cross
# 4                 GB          ar             SA            British Red Cross
# 5                 GB          fr             FR            British Red Cross
# 6                 GB          es             ES            British Red Cross
# 7                 GB          ar             SA            British Red Cross
# 8                 GB          fr             FR            British Red Cross
# 9                 GB          es             ES            British Red Cross
# 10                GB          ar             SA            British Red Cross
# 11                GB          fr             FR            British Red Cross
# 12                GB          es             ES            British Red Cross
# 13                US          fr             FR            British Red Cross
# 14                US          fr             FR  Translators without Borders
# 15                US          fr             FR            British Red Cross
# 16                GB          fr             FR           Impact initiatives
# 17                GB          fr             FR           Impact initiatives
# 18                GB          fr             FR           Impact initiatives
# 19                GB          fr             FR           Impact initiatives
# 20                GB          fr             FR           Impact initiatives
# 21                GB          fr             FR           Impact initiatives
# 22                GB          fr             FR           Impact initiatives
# 23                US          fr             CA                  Freedom Now
# 24                GB          sq             AL            British Red Cross
# 25                GB          sq             AL            British Red Cross
# 26                GB          ar             SA            British Red Cross
# 27                GB          ar             SA            British Red Cross
# 28                GB          hy             AM            British Red Cross
# 29                GB          az             AZ            British Red Cross
# ...              ...         ...            ...                          ...
# 34519             IN          en             US  Translators without Borders
# 34520             IN          en             US  Translators without Borders
# 34521             IN          en             US  Translators without Borders
# 34522             US          bn             IN  Translators without Borders
# 34523             US          bn             IN  Translators without Borders
# 34524             IN          en             US  Translators without Borders
# 34525             IN          en             US  Translators without Borders
# 34526             IN          en             US  Translators without Borders
# 34527             IN          en             US  Translators without Borders
# 34528             IN          en             US  Translators without Borders
# 34529             IN          en             US  Translators without Borders
# 34530             IN          en             US  Translators without Borders
# 34531             GB          nl             NL      The Womanity Foundation
# 34532             GB          es             ES      The Womanity Foundation
# 34533             GB          ar             SA                  Smile Train
# 34534             GB          bg             BG                  Smile Train
# 34535             GB          zh             CN                  Smile Train
# 34536             GB          hr             HR                  Smile Train
# 34537             GB          fr             FR                  Smile Train
# 34538             GB          gu             IN                  Smile Train
# 34539             GB          hi             IN                  Smile Train
# 34540             GB          id             ID                  Smile Train
# 34541             GB          pa             IN                  Smile Train
# 34542             GB          pt             BR                  Smile Train
# 34543             GB          ru             RU                  Smile Train
# 34544             GB          es             MX                  Smile Train
# 34545             GB          sw             KE                  Smile Train
# 34546             GB          tr             TR                  Smile Train
# 34547             GB          uk             UA                  Smile Train
# 34548             GB          vi             VN                  Smile Train
#
#       Format  System
# 0        doc  Kató 1
# 1        doc  Kató 1
# 2        doc  Kató 1
# 3        doc  Kató 1
# 4        ppt  Kató 1
# 5        ppt  Kató 1
# 6        ppt  Kató 1
# 7        xls  Kató 1
# 8        xls  Kató 1
# 9        xls  Kató 1
# 10       doc  Kató 1
# 11       doc  Kató 1
# 12       doc  Kató 1
# 13       doc  Kató 1
# 14       doc  Kató 1
# 15       doc  Kató 1
# 16       doc  Kató 1
# 17       doc  Kató 1
# 18       doc  Kató 1
# 19       doc  Kató 1
# 20       doc  Kató 1
# 21       doc  Kató 1
# 22       doc  Kató 1
# 23       doc  Kató 1
# 24       doc  Kató 1
# 25       doc  Kató 1
# 26       doc  Kató 1
# 27       doc  Kató 1
# 28       doc  Kató 1
# 29       doc  Kató 1
# ...      ...     ...
# 34519    doc  Kató 1
# 34520    doc  Kató 1
# 34521    doc  Kató 1
# 34522    doc  Kató 1
# 34523    doc  Kató 1
# 34524    doc  Kató 1
# 34525    doc  Kató 1
# 34526    doc  Kató 1
# 34527    doc  Kató 1
# 34528    doc  Kató 1
# 34529    doc  Kató 1
# 34530    doc  Kató 1
# 34531    doc  Kató 2
# 34532    ppt  Kató 2
# 34533    doc  Kató 1
# 34534    doc  Kató 1
# 34535    doc  Kató 1
# 34536    doc  Kató 1
# 34537    doc  Kató 1
# 34538    doc  Kató 1
# 34539    doc  Kató 1
# 34540    doc  Kató 1
# 34541    doc  Kató 1
# 34542    doc  Kató 1
# 34543    doc  Kató 1
# 34544    doc  Kató 1
# 34545    doc  Kató 1
# 34546    doc  Kató 1
# 34547    doc  Kató 1
# 34548    doc  Kató 1
#
# [34549 rows x 10 columns]

# %%
# store all sdlxliff filenames into a list
document_names = []

# trying to get all doc documents based on extensions
for document in os.listdir(data_dir):    
    if fnmatch.fnmatch(document,'*.sdlxliff'):
        '''
        if fnmatch.fnmatch(document,'*.doc*'):
            document_names.append(document)
        elif fnmatch.fnmatch(document,'*.DOC*'):
            document_names.append(document)
        elif fnmatch.fnmatch(document,'*.txt*'):
            document_names.append(document)    
        elif fnmatch.fnmatch(document,'*.pdf*'):
            document_names.append(document)
        elif fnmatch.fnmatch(document,'*.PDF*'):
            document_names.append(document)
        elif fnmatch.fnmatch(document,'*.odt*'):
            document_names.append(document)
        elif fnmatch.fnmatch(document,'*.rtf*'):
            document_names.append(document)
        elif fnmatch.fnmatch(document,'*.dotx*'):
            document_names.append(document)
        '''
        document_names.append(document)

# %%
# get the translated contents of all documents
document_contents = []
document_source_langs = []
document_target_langs = []

for i in range(len(document_names)):
    document = document_names[i]
    temp_xliff = xliff.XLIFF(data_dir + document)
    document_contents.append(temp_xliff.source)
    document_source_langs.append(temp_xliff.source_lang)
    document_target_langs.append(temp_xliff.target_lang)

# %%
# same unicode fix as for accepted_documents
for i in range(len(document_names)):
    document_names[i] = NFD(document_names[i])

# %%
# remove the sdlxliff extension as most files in the metadata are without it
filenames = []
for i in range(len(document_names)):
    filenames.append(document_names[i].replace('.sdlxliff', ''))

# %%
# find the documents that most probably have no metadata, they are a lot
documents_without_metadata = []

count = 0
for name in filenames:
    temp = metadata.loc[metadata['Filename'] == name]
    if temp.empty:
        # for the special case that the translated version's extension is used
        temp2 = metadata.loc[metadata['Filename'] == name + '.sdlxliff']
        if temp2.empty:
            count += 1       
            documents_without_metadata.append(name)

print(count)
# Out:
# 3151

# %%
# find the few entries in the metadata that are not in the documents 
# and the corresponding document filenames for the metadata filenames with wrong encoding
import difflib

filename_correspondence = {}
count = 0
for name in list(metadata['Filename'].drop_duplicates()):
    if name not in filenames and name not in document_names:
        max_similarity = 0.0
        corresponding_document = None
        for filename in filenames:
            # filename letter similarity
            seq = difflib.SequenceMatcher(None, filename, name)
            if (seq.ratio() > max_similarity):
                max_similarity = seq.ratio()
                corresponding_document = filename
        # this threshold was manually checked and it produces only one false positive
        if max_similarity > 0.5:
            filename_correspondence[name] = corresponding_document
        else:
            count += 1
            print(name)

# delete the false positive 
del filename_correspondence['Patient_Release_Form_-_Final_4.25.docx']                
print(count)
# Out:
# Ø·Ø¹Ø§Ù_x0085_Ù_x0083_Ù_x0085__Ø§Ù_x0084_Ù_x008a_Ù_x0088_Ù_x0085_.docx
# å_x0080__x008b_äººè_x0087_ªå_x0082_³.docx
# 2

# %%
# helper function that changes the wrongly encoded metadata filenames
def change_names(x):
    if x in filename_correspondence.keys():
        return filename_correspondence[x]
    else:
        return x

# start combining all present features/data per document
all_document_data = metadata
all_document_data['Filename'] = metadata['Filename'].apply(lambda x: change_names(x))

# combine document lines into one list instead of a list of lists for use in a DataFrame column
contents = []
for i in range(len(document_contents)):
    temp = ''
    for j in range(len(document_contents[i])):
        temp += document_contents[i][j] + ' '
    contents.append(temp)

# left inner join of DataFrames
# all_document_data contains information on all documents with content that have also metadata
name_contents = pd.DataFrame(columns=['Filename','Content'])
name_contents['Filename'] = filenames
name_contents['Content'] = contents
all_document_data = pd.merge(all_document_data,name_contents)

# %%
# verify which documents are missing from the previous DataFrame
s1 = set(all_document_data['Filename'])
s2 = set(name_contents['Filename'])
no_metadata = list(s2.difference(s1))

# create another DataFrame that contains only the filename, 
# source language, target language and content of these documents
no_metadata_source_langs = []
no_metadata_target_langs = []
no_metadata_contents = []

for i in no_metadata:
    j = filenames.index(i)
    no_metadata_source_langs.append(document_source_langs[j])
    no_metadata_target_langs.append(document_target_langs[j])
    no_metadata_contents.append(contents[j])

no_metadata_df = pd.DataFrame(columns=['Filename', 'Source_lang', 'Target_lang', 'Content'])
no_metadata_df['Source_lang'] = no_metadata_source_langs
no_metadata_df['Target_lang'] = no_metadata_target_langs
no_metadata_df['Content'] = no_metadata_contents
no_metadata_df['Filename'] = no_metadata

# %%
# find only documents in the english language
from langdetect import detect

# detect the document contents language if possible
def detect_helper(x):
    try:
        temp = detect(x)
    except:
        temp = 'No'
    return temp

# keep only the english documents in both datasets
languages = all_document_data['Content'].apply(lambda x: detect_helper(x))
english_document_data = all_document_data[languages == 'en']

languages2 = no_metadata_df['Content'].apply(detect_helper)
english_no_metadata_df = no_metadata_df[languages2 == 'en']

# %%
import nltk

# add average sentence length as a feature(it was mentioned by the challenge owners, thought it could be interesting)
def avg_sent_len(x):
    acc = 0
    sents = nltk.sent_tokenize(x)
    if len(sents) == 0:
        return 0
    for sent in sents:
        acc += len(nltk.word_tokenize(sent))
    return acc/len(sents)
                                         
english_document_data['Average Sentence Length'] = english_document_data['Content'].apply(avg_sent_len)
english_no_metadata_df['Average Sentence Length'] = english_no_metadata_df['Content'].apply(avg_sent_len)

# %%
# cache to disk for easier use
english_document_data.to_pickle('data/english_document_data.pkl')
english_no_metadata_df.to_pickle('data/english_no_metadata.pkl')

# %% [markdown]
# ## Stemming

# %%
import nltk
from nltk.stem import PorterStemmer
#from nltk.stem import LancasterStemmer
#nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer

tokenizer = RegexpTokenizer(r'\w+')
porter = PorterStemmer()

from nltk.tokenize import sent_tokenize, word_tokenize
def stemSentence(sentence):
    token_words=tokenizer.tokenize(sentence)
    token_words
    stop_words = set(stopwords.words('english'))
    #print(stop_words)
    filter_sentense = [w for w in token_words if not w in stop_words]
    
    stem_sentence=[]
    for word in filter_sentense:
        stem_sentence.append(porter.stem(word))
        stem_sentence.append(" ")
    return "".join(stem_sentence)

# %%
# testing tokenizer function
n=16880
filename = all_document_data['Filename'].iloc[n]
sentence = all_document_data['Content'].iloc[n]
token_words = tokenizer.tokenize(filename)
print(filename)
print(sentence)
print(token_words)
# Out:
# Instructions-Leaflet2_ENglish_(2).docx
# THIS IS YOUR FREE MICRO SD CARD FROM REFUCOMM IT CONTAINS ESSENTIAL INFORMATION FOR YOU  There are many different rules and procedures in Greece. This card contains VITAL information on these procedures and how you can prepare for them. You will NOT get this information from the authorities. All our information has been checked by lawyers. You do not need to use the internet to access the information. It is free! There is information in document and film format on this SD card in Arabic, Farsi, Dari, Urdu, French, Sorani and Kurmanji.  HOW TO USE Look for a place on your phone to insert the SD card; see images below for the usual locations. Most phones have one of these, if you can’t find it, ask a friend for help. 		 in the side of your phone	in the back of your phone	in the top of your phone If your phone does not have a place for SD cards you can get the information from a friend’s phone via Bluetooth (see overleaf). If you cannot open the documents you need to download a PDF viewer on your phone. To do this go to the Google Play Store, search for “PDF viewer”, and select “install”. Remember there is space on the card to save copies of important documents (photos of your identification, doctor’s notes and any papers you might need as evidence for your asylum case). Keep the SD card somewhere safe outside of your phone. If your phone is confiscated by the authorities, or lost, you will still have access to your documents, photos and the information when you have access to another phone or computer. SHARING VIA BLUETOOTH You can share the information from phone to phone via Bluetooth - share with your family and friends! Turn on Bluetooth on both phones using the Bluetooth symbol Select ‘pair with a device’ to connect with each other’s phones You will be sent a verification code - enter this Select send files. UPDATES The procedures and rules can changes at any time. For emergency updates on information and assistance, join the Refugee InfoBus Whatsapp group (0030 694 011 0958). Find RefuComm on Facebook where we can answer your questions and post information updates: Farsi, Urdu & English: www.facebook.com/refucomm Arabic speakers: www.facebook.com/refucommarabic Knowledge is power! Stay informed and peace be with you. With love from the RefuComm team www.refucomm.com  Instructions Leaflet.indd    03/08/2017   20:15
# ['Instructions', 'Leaflet2_ENglish_', '2', 'docx']

# %%
# testing stemSentence function
x=tokenizer.tokenize(stemSentence(sentence))
print(x)
# Out:
# ['thi', 'IS', 'your', 'free', 'micro', 'SD', 'card', 'from', 'refucomm', 'IT', 'contain', 'essenti', 'inform', 'for', 'you', 'there', 'mani', 'differ', 'rule', 'procedur', 'greec', 'thi', 'card', 'contain', 'vital', 'inform', 'procedur', 'prepar', 'you', 'not', 'get', 'inform', 'author', 'all', 'inform', 'check', 'lawyer', 'you', 'need', 'use', 'internet', 'access', 'inform', 'It', 'free', 'there', 'inform', 'document', 'film', 'format', 'SD', 'card', 'arab', 'farsi', 'dari', 'urdu', 'french', 'sorani', 'kurmanji', 'how', 'TO', 'use', 'look', 'place', 'phone', 'insert', 'SD', 'card', 'see', 'imag', 'usual', 'locat', 'most', 'phone', 'one', 'find', 'ask', 'friend', 'help', 'side', 'phone', 'back', 'phone', 'top', 'phone', 'If', 'phone', 'place', 'SD', 'card', 'get', 'inform', 'friend', 'phone', 'via', 'bluetooth', 'see', 'overleaf', 'If', 'cannot', 'open', 'document', 'need', 'download', 'pdf', 'viewer', 'phone', 'To', 'go', 'googl', 'play', 'store', 'search', 'pdf', 'viewer', 'select', 'instal', 'rememb', 'space', 'card', 'save', 'copi', 'import', 'document', 'photo', 'identif', 'doctor', 'note', 'paper', 'might', 'need', 'evid', 'asylum', 'case', 'keep', 'SD', 'card', 'somewher', 'safe', 'outsid', 'phone', 'If', 'phone', 'confisc', 'author', 'lost', 'still', 'access', 'document', 'photo', 'inform', 'access', 'anoth', 'phone', 'comput', 'share', 'via', 'bluetooth', 'you', 'share', 'inform', 'phone', 'phone', 'via', 'bluetooth', 'share', 'famili', 'friend', 'turn', 'bluetooth', 'phone', 'use', 'bluetooth', 'symbol', 'select', 'pair', 'devic', 'connect', 'phone', 'you', 'sent', 'verif', 'code', 'enter', 'select', 'send', 'file', 'updat', 'the', 'procedur', 'rule', 'chang', 'time', 'for', 'emerg', 'updat', 'inform', 'assist', 'join', 'refuge', 'infobu', 'whatsapp', 'group', '0030', '694', '011', '0958', 'find', 'refucomm', 'facebook', 'answer', 'question', 'post', 'inform', 'updat', 'farsi', 'urdu', 'english', 'www', 'facebook', 'com', 'refucomm', 'arab', 'speaker', 'www', 'facebook', 'com', 'refucommarab', 'knowledg', 'power', 'stay', 'inform', 'peac', 'with', 'love', 'refucomm', 'team', 'www', 'refucomm', 'com', 'instruct', 'leaflet', 'indd', '03', '08', '2017', '20', '15']

# %%
from TWB.nlp import extract_words

# create pd data frame "Stems" and save all the stemed Filenames and Content
stems = pd.DataFrame(index=all_document_data.index, columns=['Filename','Content'])
for i in all_document_data.index:
    filename = all_document_data['Filename'].iloc[i]
    content = all_document_data['Content'].iloc[i]
    stems.Filename[i] = " ".join(extract_words(filename.replace("_", " ")))
    stems.Content[i] = " ".join(extract_words(content.replace("_", " ")))

# %%
stems.Content.describe
# Out:
# <bound method NDFrame.describe of 0        thi test thi test thi test thi test thi test t...
# 1        thi test thi test thi test thi test thi test t...
# 2        thi test thi test thi test thi test thi test t...
# 3        thi test thi test thi test thi test thi test t...
# 4        thi test thi test thi test thi test thi test t...
# 5        thi test thi test thi test thi test thi test t...
# 6        thi test thi test thi test thi test thi test t...
# 7        thi test thi test thi test thi test thi test t...
# 8        thi test thi test thi test thi test thi test t...
# 9        thi test thi test thi test thi test thi test t...
# 10       thi test thi test thi test thi test thi test t...
# 11       thi test thi test thi test thi test thi test t...
# 12       thi test thi test thi test thi test thi test t...
# 13       grt strength high qualiti resourc scale scope ...
# 14       grt strength high qualiti resourc scale scope ...
# 15       grt strength high qualiti resourc scale scope ...
# 16       fact individu eru D heop rdrt rit individu fac...
# 17       fact individu eru D heop rdrt rit individu fac...
# 18       fact individu eru D heop rdrt rit individu fac...
# 19       global tool review final report 30 novemb 2016...
# 20       global tool review final report 30 novemb 2016...
# 21       global tool review final report 30 novemb 2016...
# 22       includ AN imag map OR pictur format cover page...
# 23       includ AN imag map OR pictur format cover page...
# 24       includ AN imag map OR pictur format cover page...
# 25       includ AN imag map OR pictur format cover page...
# 26       includ AN imag map OR pictur format cover page...
# 27       includ AN imag map OR pictur format cover page...
# 28       includ AN imag map OR pictur format cover page...
# 29       execut summari thi report repres first phase o...
#                                ...
# 34495    name ন ম fgd venu স থ ন number particip অ শগ র...
# 34496    name ন ম fgd venu স থ ন number particip অ শগ র...
# 34497    name ন ম আয়শ venu স থ ন ক য ম প ২৬ number part...
# 34498    name ন ম আয়শ venu স থ ন ক য ম প ২৬ number part...
# 34499    name ন ম আয়শ venu স থ ন ক য ম প ২৬ number part...
# 34500    name ন ম শ ফ venu স থ ন ২৬ number particip অ শ...
# 34501    name ন ম শ ফ venu স থ ন ২৬ number particip অ শ...
# 34502    name ন ম শ ফ venu স থ ন ২৬ number particip অ শ...
# 34503    name ন ম শ ফ venu স থ ন ২৬ number particip অ শ...
# 34504    name ন ম শ ফ venu স থ ন ২৬ number particip অ শ...
# 34505    name ন ম ন গ র স লত ন venu স থ ন ক য ম প ২৬ nu...
# 34506    name ন ম ন গ র স লত ন venu স থ ন ক য ম প ২৬ nu...
# 34507    name ন ম ন গ র স লত ন venu স থ ন ক য ম প ২৬ nu...
# 34508    name ন ম আজ হ র আলম র ব ব venu স থ ন number pa...
# 34509    name ন ম আজ হ র আলম র ব ব venu স থ ন number pa...
# 34510    name ন ম আজ হ র আলম র ব ব venu স থ ন number pa...
# 34511    name ন ম দ ল য় র ইসল ম venu স থ ন number parti...
# 34512    name ন ম দ ল য় র ইসল ম venu স থ ন number parti...
# 34513    name ন ম দ ল য় র ইসল ম venu স থ ন number parti...
# 34514    name ন ম আয় শ আকত র venu স থ ন ক য ম প ৫ ১৭ nu...
# 34515    name ন ম আয় শ আকত র venu স থ ন ক য ম প ৫ ১৭ nu...
# 34516    name ন ম আয় শ আকত র venu স থ ন ক য ম প ৫ ১৭ nu...
# 34517    name ন ম আয় শ আকত র venu স থ ন ক য ম প ৫ ১৭ nu...
# 34518    name ন ম আবদ ল ক দ র venu স থ ন number partici...
# 34519    name ন ম আবদ ল ক দ র venu স থ ন number partici...
# 34520    name ন ম আবদ ল ক দ র venu স থ ন number partici...
# 34521    twb languag barrier research onlin survey cox ...
# 34522    twb languag barrier research onlin survey cox ...
# 34523    project A nice place foundat durat 2 year loca...
# 34524    start fund start humanitarian pool fund run ng...
# Name: Content, Length: 34525, dtype: object>

# %%
tags = ['humanitarian crisis',
        'natural disaster',
        'environmental crisis',        
        'disability',
        'gender',
        'genital mutilation',
        'racism',
        'genocide',
        'civil war',
        'terrorism',
        'infectious disease',
        'political revolution',
        'political prisoner',
        'amnesty',
        'corruption',
        'health awareness',
        'gender inequality',
        'rape',
        'ebola',
        'aids',
        'first aid',
        'emergency',
        'disease',
        'operation',
        'virus',
        'response',
        'protocol',
        'certificate',
        'medication',
        'elderly',
        'children',
        'adults',
        'men',
        'women',
        'disabled',
        'old',
        'teenagers',
        'kids',
        'male',
        'female'
       ]

# remove possible duplicates
tags = set(tags)
tags = list(tags)

# %%
stemSentence(tags[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-500c1335722a> in <module>
# ----> 1 stemSentence(tags[0])
#
# NameError: name 'stemSentence' is not defined

# %%
# stemming the tags and saving them to a df 
impactful_dict = pd.DataFrame(index=range(len(tags)), columns=['Stems'])
i =0
for w in tags:
    impactful_dict.Stems[i]= " ".join(extract_words(w))
    i += 1

# %%
impactful_dict.describe
# Out:
# <bound method NDFrame.describe of                  Stems
# 0            civil war
# 1               racism
# 2                  kid
# 3                emerg
# 4         natur disast
# 5                ebola
# 6               terror
# 7              respons
# 8             children
# 9                femal
# 10             genocid
# 11               women
# 12                 aid
# 13  humanitarian crisi
# 14                rape
# 15             elderli
# 16      infecti diseas
# 17               adult
# 18              teenag
# 19         genit mutil
# 20               medic
# 21                 old
# 22                 men
# 23              gender
# 24        polit prison
# 25                oper
# 26              certif
# 27              diseas
# 28                male
# 29              disabl
# 30             corrupt
# 31                viru
# 32            protocol
# 33           first aid
# 34        gender inequ
# 35             amnesti
# 36         health awar
# 37   environment crisi
# 38              disabl
# 39       polit revolut>

# %% [markdown]
# ## Compute Relative Freqs of tags in the Contents and Filenames

# %%
import re

# %%
# testing word counts and freqs
text = stems.Content[0]
# text = 'paok paok paok paok paok paok paok test'
givenWord = 'test'
total = len(re.findall(r'\w+', text)) 
count = len(re.findall('\w*'+ givenWord +'\w*', text))
print(total)
print(count)
print(count/total)
# Out:
# 173
# 87
# 0.5028901734104047

# %%
# function that returns the relative freq of spercific word in str
def word_relativ_Freq(text, givenWord):
    total = len(re.findall(r'\w+', text)) 
    count = len(re.findall('\w*'+ givenWord +'\w*', text))
    if total==0:
        return 0
    relFreq = count/total
    return relFreq

# %%
# create a data frame with the relative freqs of stemed tags per document content
freq_content = pd.DataFrame(index= all_document_data.index, columns=impactful_dict.Stems)

# %%
import time
start_time = time.time()

for j in impactful_dict.Stems:
    freq_content[j] = stems.Content.apply(lambda x: word_relativ_Freq(x,j))

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 1908.7024607658386 seconds ---

# %%
freq_content.describe()
# Out:
# Stems     civil war        racism           kid         emerg  natur disast  \
# count  34525.000000  34525.000000  34525.000000  34525.000000  34525.000000
# mean       0.000010      0.000006      0.000155      0.002054      0.000058
# std        0.000211      0.000134      0.002565      0.006872      0.000681
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000878      0.000000
# max        0.010870      0.005726      0.127660      0.111111      0.056604
#
# Stems         ebola        terror       respons      children         femal  \
# count  34525.000000  34525.000000  34525.000000  34525.000000  34525.000000
# mean       0.000213      0.000019      0.002752      0.003340      0.000254
# std        0.002504      0.000220      0.007720      0.008386      0.001446
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000278      0.000000      0.000000
# 75%        0.000000      0.000000      0.002740      0.002133      0.000000
# max        0.166667      0.008696      0.166667      0.125000      0.090909
#
# Stems      ...             corrupt          viru      protocol     first aid  \
# count      ...        34525.000000  34525.000000  34525.000000  34525.000000
# mean       ...            0.000167      0.000308      0.000198      0.000409
# std        ...            0.002248      0.002945      0.001089      0.004437
# min        ...            0.000000      0.000000      0.000000      0.000000
# 25%        ...            0.000000      0.000000      0.000000      0.000000
# 50%        ...            0.000000      0.000000      0.000000      0.000000
# 75%        ...            0.000000      0.000000      0.000000      0.000000
# max        ...            0.056805      0.072072      0.022543      0.166667
#
# Stems  gender inequ       amnesti   health awar  environment crisi  \
# count  34525.000000  34525.000000  34525.000000       3.452500e+04
# mean       0.000016      0.000013      0.000003       3.524379e-08
# std        0.000262      0.000361      0.000418       1.890121e-06
# min        0.000000      0.000000      0.000000       0.000000e+00
# 25%        0.000000      0.000000      0.000000       0.000000e+00
# 50%        0.000000      0.000000      0.000000       0.000000e+00
# 75%        0.000000      0.000000      0.000000       0.000000e+00
# max        0.023256      0.021739      0.076923       1.013993e-04
#
# Stems        disabl  polit revolut
# count  34525.000000        34525.0
# mean       0.001390            0.0
# std        0.006749            0.0
# min        0.000000            0.0
# 25%        0.000000            0.0
# 50%        0.000000            0.0
# 75%        0.000000            0.0
# max        0.125874            0.0
#
# [8 rows x 40 columns]

# %%
# create a data frame with the relative freqs of stemed tags per document filename
freq_filename = pd.DataFrame(index= all_document_data.index, columns=impactful_dict.Stems)
for j in impactful_dict.Stems:
    freq_filename[j] = stems.Filename.apply(lambda x: word_relativ_Freq(x,j))

# %%
freq_filename.describe()
# Out:
# Stems     civil war   racism           kid         emerg  natur disast  \
# count  34525.000000  34525.0  34525.000000  34525.000000  34525.000000
# mean       0.000004      0.0      0.000135      0.001527      0.000021
# std        0.000483      0.0      0.004589      0.015395      0.001780
# min        0.000000      0.0      0.000000      0.000000      0.000000
# 25%        0.000000      0.0      0.000000      0.000000      0.000000
# 50%        0.000000      0.0      0.000000      0.000000      0.000000
# 75%        0.000000      0.0      0.000000      0.000000      0.000000
# max        0.062500      0.0      0.166667      0.333333      0.166667
#
# Stems         ebola   terror       respons      children         femal  \
# count  34525.000000  34525.0  34525.000000  34525.000000  34525.000000
# mean       0.000460      0.0      0.001669      0.001044      0.000329
# std        0.009115      0.0      0.015973      0.012664      0.005408
# min        0.000000      0.0      0.000000      0.000000      0.000000
# 25%        0.000000      0.0      0.000000      0.000000      0.000000
# 50%        0.000000      0.0      0.000000      0.000000      0.000000
# 75%        0.000000      0.0      0.000000      0.000000      0.000000
# max        0.333333      0.0      0.500000      0.250000      0.142857
#
# Stems      ...             corrupt          viru      protocol     first aid  \
# count      ...        34525.000000  34525.000000  34525.000000  34525.000000
# mean       ...            0.000412      0.000025      0.000687      0.000977
# std        ...            0.006682      0.001533      0.011074      0.012845
# min        ...            0.000000      0.000000      0.000000      0.000000
# 25%        ...            0.000000      0.000000      0.000000      0.000000
# 50%        ...            0.000000      0.000000      0.000000      0.000000
# 75%        ...            0.000000      0.000000      0.000000      0.000000
# max        ...            0.333333      0.142857      0.250000      0.250000
#
# Stems  gender inequ  amnesti   health awar  environment crisi        disabl  \
# count       34525.0  34525.0  34525.000000            34525.0  34525.000000
# mean            0.0      0.0      0.000006                0.0      0.000940
# std             0.0      0.0      0.001076                0.0      0.011007
# min             0.0      0.0      0.000000                0.0      0.000000
# 25%             0.0      0.0      0.000000                0.0      0.000000
# 50%             0.0      0.0      0.000000                0.0      0.000000
# 75%             0.0      0.0      0.000000                0.0      0.000000
# max             0.0      0.0      0.200000                0.0      0.250000
#
# Stems  polit revolut
# count        34525.0
# mean             0.0
# std              0.0
# min              0.0
# 25%              0.0
# 50%              0.0
# 75%              0.0
# max              0.0
#
# [8 rows x 40 columns]

# %% [markdown]
# Finding labels of the documents

# %%
# defining function to check buzz word 
def exist_(temp,j): 
    temp2=temp.lower()
    temp3=temp2.find(j)
    return temp3>0
    
dictionary2=['certificate','instruction','poster','protocol','response','letter','report','map','manual','banner']

for j in dictionary2:
    jj=english_document_data.Filename.apply(lambda x: exist_(x,j))
    rr=pd.DataFrame(columns=[str(j)])
    rr[str(j)]=jj
    english_document_data=pd.concat([english_document_data,rr ], axis=1)

# %%
# cache intermediate data
stems.to_pickle('data/stemmed_data.pkl')
freq_content.to_pickle('data/freq_content.pkl')
freq_filename.to_pickle('data/freq_filename.pkl')
english_document_data.to_pickle('data/english_document_data_categories.pkl')
#tfidf_df.to_pickle('data/tfidf.pkl')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

stems = pd.read_pickle('data/stemmed_data.pkl')

vectorizer = TfidfVectorizer()
tfidfs = vectorizer.fit_transform(stems['Content'])

# this also has a memory error
print(tfidfs.toarray())

# %%
# read cached data
#english_document_data = pd.read_pickle('data/english_document_data.pkl')
#freq_content = pd.read_pickle('data/freq_content.pkl')

# aggregate tags that refer to the same people group
def combine_tags(tag_list, entry):
    max_tag = 0.0
    tag = -1
    for i in range(len(tag_list)):
        temp = 0
        for j in tag_list[i]:
            temp += entry[j]
        if temp > max_tag:
            max_tag = temp
            tag = i
    return tag


# tags refer to: -1 -> Undefined, 0 -> 65+, 1 -> 0-18, 2 -> 18-65 
age_tag_pairs = [['elderli','old'],['children','kid','teenag'],['adult']]
age_tag_pair_inds = []
for tag_pair in age_tag_pairs:
    temp = []
    for tag in tag_pair:
        temp.append(freq_content.columns.get_loc(tag))
    age_tag_pair_inds.append(temp)
    
print(age_tag_pair_inds)

# tags refer to: -1 -> Undefined, 0 -> Male, 1 -> Female
gender_tag_pairs = [['male','men'], ['femal','women']]
gender_tag_pair_inds = []
for tag_pair in gender_tag_pairs:
    temp = []
    for tag in tag_pair:
        temp.append(freq_content.columns.get_loc(tag))
    gender_tag_pair_inds.append(temp)

print(gender_tag_pair_inds)

# populate a list with age and gender values for each row in the english documents
gender = []
age = []
for i in range(len(freq_content)):
    gender.append(combine_tags(gender_tag_pair_inds,freq_content.iloc[i]))
    age.append(combine_tags(age_tag_pair_inds,freq_content.iloc[i]))
# Out:
# [[15, 21], [8, 2, 18], [17]]
# [[28, 22], [9, 11]]

# %%
# put the lists into the tag frequencies per document DataFrame
gender2 = pd.DataFrame(gender)
age2 = pd.DataFrame(age) 
freq_content['Age'] = age2
freq_content['Gender'] = gender2

# %%
# find documents without NGO values
metadata.loc[metadata['NGO'].isna(),'NGO'] = 'Undefined'

# calculate the amount of translations requested by each document
ngo_docs = metadata.groupby('NGO').aggregate('count')['System']

# sanity check
print(len(metadata['NGO'].unique()))

# sanity check
total_docs = 0
for i in ngo_docs:
    total_docs += i
print(total_docs)

# sanity check
print(len(metadata))
sc = (metadata['NGO'].apply(pd.isna))
metadata.loc[sc]

# calculate each NGO's portion of documents from the corpus to be used as a weight
ngo_docs = ngo_docs/total_docs
# Out:
# 258
# 34549
# 34549

# %%
# cache intermediate data
ngo_docs.to_pickle('data/ngo_weights.pkl')
freq_content.to_pickle('data/freq_content_updated.pkl')

# %%
# create labels for the topic of documents(as given by the challenge owners) based on the title
dictionary3=['health','logistics','nutrition','protection','shelter','water','sanitation','hygiene','camp coordination','camp management','early recovery','education','emergency telecommunications','food security']

extra_features = pd.DataFrame(index=english_document_data.index)
for j in dictionary3:
    jj=english_document_data.Filename.apply(lambda x: exist_(x,j))
    rr=pd.DataFrame(columns=[str(j)])
    rr[str(j)]=jj
    extra_features=pd.concat([extra_features,rr ], axis=1)

# %%
# combine some topics that were given together
extra_features['water/sanitation/hygiene'] = (extra_features['water'] | extra_features['sanitation'] | extra_features['hygiene'])
extra_features['camp coordination/camp management'] = (extra_features['camp coordination'] | extra_features['camp management'])

# check the amount of documents per topic
for i in dictionary3:
    print(i,len(extra_features[extra_features[i]]))

# drop the single columns that are part of the combined ones
extra_features = extra_features.loc[:,~np.array([False, False, False, False, False, True, True, True, True,True, False, False, False, False, False, False])]
dictionary4 = ['health','logistics','nutrition','protection','shelter','water/sanitation/hygiene','camp coordination/camp management','early recovery','education','emergency telecommunications','food security']

# sanity check
for i in dictionary4:
    print(i,len(extra_features[extra_features[i]]))
# Out:
# health 431
# logistics 18
# nutrition 160
# protection 157
# shelter 95
# water 47
# sanitation 0
# hygiene 19
# camp coordination 0
# camp management 0
# early recovery 0
# education 345
# emergency telecommunications 0
# food security 0
# health 431
# logistics 18
# nutrition 160
# protection 157
# shelter 95
# water/sanitation/hygiene 66
# camp coordination/camp management 0
# early recovery 0
# education 345
# emergency telecommunications 0
# food security 0

# %%
extra_features.to_pickle('data/english_document_data_topics.pkl')

# %%
extra_features
# Out:
#        health  logistics  nutrition  protection  shelter  early recovery  \
# 0       False      False      False       False    False           False
# 1       False      False      False       False    False           False
# 2       False      False      False       False    False           False
# 3       False      False      False       False    False           False
# 4       False      False      False       False    False           False
# 5       False      False      False       False    False           False
# 6       False      False      False       False    False           False
# 7       False      False      False       False    False           False
# 8       False      False      False       False    False           False
# 9       False      False      False       False    False           False
# 10      False      False      False       False    False           False
# 11      False      False      False       False    False           False
# 12      False      False      False       False    False           False
# 13      False      False      False       False    False           False
# 14      False      False      False       False    False           False
# 15      False      False      False       False    False           False
# 16      False      False      False       False    False           False
# 17      False      False      False       False    False           False
# 18      False      False      False       False    False           False
# 19      False      False      False       False    False           False
# 20      False      False      False       False    False           False
# 21      False      False      False       False    False           False
# 22      False      False      False       False    False           False
# 23      False      False      False       False    False           False
# 24      False      False      False       False    False           False
# 25      False      False      False       False    False           False
# 26      False      False      False       False    False           False
# 27      False      False      False       False    False           False
# 28      False      False      False       False    False           False
# 29      False      False      False       False    False           False
# ...       ...        ...        ...         ...      ...             ...
# 34459   False      False      False       False    False           False
# 34460   False      False      False       False    False           False
# 34461   False      False      False       False    False           False
# 34462   False      False      False       False    False           False
# 34463   False      False      False       False    False           False
# 34464   False      False      False       False    False           False
# 34465   False      False      False       False    False           False
# 34466   False      False      False       False    False           False
# 34467   False      False      False       False    False           False
# 34468   False      False      False       False    False           False
# 34469   False      False      False       False    False           False
# 34470   False      False      False       False    False           False
# 34471   False      False      False       False    False           False
# 34472   False      False      False       False    False           False
# 34473   False      False      False       False    False           False
# 34474   False      False      False       False    False           False
# 34475   False      False      False       False    False           False
# 34476   False      False      False       False    False           False
# 34477   False      False      False       False    False           False
# 34478   False      False      False       False    False           False
# 34479   False      False      False       False    False           False
# 34480   False      False      False       False    False           False
# 34481   False      False      False       False    False           False
# 34482   False      False      False       False    False           False
# 34483   False      False      False       False    False           False
# 34484   False      False      False       False    False           False
# 34521   False      False      False       False    False           False
# 34522   False      False      False       False    False           False
# 34523   False      False      False       False    False           False
# 34524   False      False      False       False    False           False
#
#        education  emergency telecommunications  food security  \
# 0          False                         False          False
# 1          False                         False          False
# 2          False                         False          False
# 3          False                         False          False
# 4          False                         False          False
# 5          False                         False          False
# 6          False                         False          False
# 7          False                         False          False
# 8          False                         False          False
# 9          False                         False          False
# 10         False                         False          False
# 11         False                         False          False
# 12         False                         False          False
# 13         False                         False          False
# 14         False                         False          False
# 15         False                         False          False
# 16         False                         False          False
# 17         False                         False          False
# 18         False                         False          False
# 19         False                         False          False
# 20         False                         False          False
# 21         False                         False          False
# 22         False                         False          False
# 23         False                         False          False
# 24         False                         False          False
# 25         False                         False          False
# 26         False                         False          False
# 27         False                         False          False
# 28         False                         False          False
# 29         False                         False          False
# ...          ...                           ...            ...
# 34459      False                         False          False
# 34460      False                         False          False
# 34461      False                         False          False
# 34462      False                         False          False
# 34463      False                         False          False
# 34464      False                         False          False
# 34465      False                         False          False
# 34466      False                         False          False
# 34467      False                         False          False
# 34468      False                         False          False
# 34469      False                         False          False
# 34470      False                         False          False
# 34471      False                         False          False
# 34472      False                         False          False
# 34473      False                         False          False
# 34474      False                         False          False
# 34475      False                         False          False
# 34476      False                         False          False
# 34477      False                         False          False
# 34478      False                         False          False
# 34479      False                         False          False
# 34480      False                         False          False
# 34481      False                         False          False
# 34482      False                         False          False
# 34483      False                         False          False
# 34484      False                         False          False
# 34521      False                         False          False
# 34522      False                         False          False
# 34523      False                         False          False
# 34524      False                         False          False
#
#        water/sanitation/hygiene  camp coordination/camp management
# 0                         False                              False
# 1                         False                              False
# 2                         False                              False
# 3                         False                              False
# 4                         False                              False
# 5                         False                              False
# 6                         False                              False
# 7                         False                              False
# 8                         False                              False
# 9                         False                              False
# 10                        False                              False
# 11                        False                              False
# 12                        False                              False
# 13                        False                              False
# 14                        False                              False
# 15                        False                              False
# 16                        False                              False
# 17                        False                              False
# 18                        False                              False
# 19                        False                              False
# 20                        False                              False
# 21                        False                              False
# 22                        False                              False
# 23                        False                              False
# 24                        False                              False
# 25                        False                              False
# 26                        False                              False
# 27                        False                              False
# 28                        False                              False
# 29                        False                              False
# ...                         ...                                ...
# 34459                     False                              False
# 34460                     False                              False
# 34461                     False                              False
# 34462                     False                              False
# 34463                     False                              False
# 34464                     False                              False
# 34465                     False                              False
# 34466                     False                              False
# 34467                     False                              False
# 34468                     False                              False
# 34469                     False                              False
# 34470                     False                              False
# 34471                     False                              False
# 34472                     False                              False
# 34473                     False                              False
# 34474                     False                              False
# 34475                     False                              False
# 34476                     False                              False
# 34477                     False                              False
# 34478                     False                              False
# 34479                     False                              False
# 34480                     False                              False
# 34481                     False                              False
# 34482                     False                              False
# 34483                     False                              False
# 34484                     False                              False
# 34521                     False                              False
# 34522                     False                              False
# 34523                     False                              False
# 34524                     False                              False
#
# [30073 rows x 11 columns]
